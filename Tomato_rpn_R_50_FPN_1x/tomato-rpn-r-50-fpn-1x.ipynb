# %%
import sys, os, distutils.core
from IPython.display import clear_output

# !python -m pip install pyyaml==5.1
# !git clone 'https://github.com/facebookresearch/detectron2'
dist = distutils.core.run_setup("./detectron2/setup.py")
# !python -m pip install {' '.join([f"'{x}'" for x in dist.install_requires])}
sys.path.insert(0, os.path.abspath('./detectron2'))
# Out:
# Collecting pyyaml==5.1
#   Downloading PyYAML-5.1.tar.gz (274 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.2/274.2 kB 7.4 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: pyyaml
#   Building wheel for pyyaml (setup.py) ... done
#   Created wheel for pyyaml: filename=PyYAML-5.1-cp310-cp310-linux_x86_64.whl size=44090 sha256=573381ccd27606edce8e1c55a076a522a6a57f4dadc3d89568cfb200f41e9ad5
#   Stored in directory: /root/.cache/pip/wheels/70/83/31/975b737609aba39a4099d471d5684141c1fdc3404f97e7f68a
# Successfully built pyyaml
# Installing collected packages: pyyaml
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0
#     Uninstalling PyYAML-6.0:
#       Successfully uninstalled PyYAML-6.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dask-cudf 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# dask 2023.9.0 requires pyyaml>=5.3.1, but you have pyyaml 5.1 which is incompatible.
# dask-cuda 23.8.0 requires dask==2023.7.1, but you have dask 2023.9.0 which is incompatible.
# dask-cuda 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.0.2 which is incompatible.
# dask-cudf 23.8.0 requires dask==2023.7.1, but you have dask 2023.9.0 which is incompatible.
# dask-cudf 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.0.2 which is incompatible.
# distributed 2023.7.1 requires dask==2023.7.1, but you have dask 2023.9.0 which is incompatible.
# distributed 2023.7.1 requires pyyaml>=5.3.1, but you have pyyaml 5.1 which is incompatible.
# flax 0.7.2 requires PyYAML>=5.4.1, but you have pyyaml 5.1 which is incompatible.
# jupyter-events 0.6.3 requires pyyaml>=5.3, but you have pyyaml 5.1 which is incompatible.
# jupyterlab-lsp 4.2.0 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# kfp 2.0.1 requires google-cloud-storage<3,>=2.2.1, but you have google-cloud-storage 1.44.0 which is incompatible.
# kfp 2.0.1 requires PyYAML<7,>=5.3, but you have pyyaml 5.1 which is incompatible.
# kubernetes 26.1.0 requires pyyaml>=5.4.1, but you have pyyaml 5.1 which is incompatible.
# pytorch-lightning 2.0.8 requires PyYAML>=5.4, but you have pyyaml 5.1 which is incompatible.
# raft-dask 23.8.0 requires dask==2023.7.1, but you have dask 2023.9.0 which is incompatible.
# ydata-profiling 4.3.1 requires scipy<1.11,>=1.4.1, but you have scipy 1.11.2 which is incompatible.
# Successfully installed pyyaml-5.1
# Cloning into 'detectron2'...
# remote: Enumerating objects: 15725, done.
# remote: Counting objects: 100% (448/448), done.
# remote: Compressing objects: 100% (337/337), done.
# remote: Total 15725 (delta 201), reused 301 (delta 102), pack-reused 15277
# Receiving objects: 100% (15725/15725), 6.51 MiB | 28.14 MiB/s, done.
# Resolving deltas: 100% (11317/11317), done.
# Requirement already satisfied: Pillow>=7.1 in /opt/conda/lib/python3.10/site-packages (9.5.0)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (3.7.2)
# Collecting pycocotools>=2.0.2
#   Downloading pycocotools-2.0.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (426 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 426.2/426.2 kB 11.6 MB/s eta 0:00:0000:01
# Requirement already satisfied: termcolor>=1.1 in /opt/conda/lib/python3.10/site-packages (2.3.0)
# Collecting yacs>=0.1.8
#   Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Requirement already satisfied: tabulate in /opt/conda/lib/python3.10/site-packages (0.9.0)
# Requirement already satisfied: cloudpickle in /opt/conda/lib/python3.10/site-packages (2.2.1)
# Requirement already satisfied: tqdm>4.29.0 in /opt/conda/lib/python3.10/site-packages (4.66.1)
# Requirement already satisfied: tensorboard in /opt/conda/lib/python3.10/site-packages (2.12.3)
# Collecting fvcore<0.1.6,>=0.1.5
#   Downloading fvcore-0.1.5.post20221221.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 4.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting iopath<0.1.10,>=0.1.7
#   Downloading iopath-0.1.9-py3-none-any.whl (27 kB)
# Collecting omegaconf<2.4,>=2.1
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 8.5 MB/s eta 0:00:00
# Collecting hydra-core>=1.1
#   Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 15.3 MB/s eta 0:00:00
# Collecting black
#   Downloading black-24.4.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 50.6 MB/s eta 0:00:00:00:01
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (21.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: PyYAML in /opt/conda/lib/python3.10/site-packages (from yacs>=0.1.8) (5.1)
# Requirement already satisfied: absl-py>=0.4 in /opt/conda/lib/python3.10/site-packages (from tensorboard) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /opt/conda/lib/python3.10/site-packages (from tensorboard) (1.51.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /opt/conda/lib/python3.10/site-packages (from tensorboard) (2.20.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /opt/conda/lib/python3.10/site-packages (from tensorboard) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.10/site-packages (from tensorboard) (3.4.3)
# Requirement already satisfied: protobuf>=3.19.6 in /opt/conda/lib/python3.10/site-packages (from tensorboard) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard) (2.31.0)
# Requirement already satisfied: setuptools>=41.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard) (68.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from tensorboard) (2.3.7)
# Requirement already satisfied: wheel>=0.26 in /opt/conda/lib/python3.10/site-packages (from tensorboard) (0.40.0)
# Collecting portalocker (from iopath<0.1.10,>=0.1.7)
#   Downloading portalocker-2.8.2-py3-none-any.whl (17 kB)
# Collecting antlr4-python3-runtime==4.9.* (from omegaconf<2.4,>=2.1)
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 11.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: click>=8.0.0 in /opt/conda/lib/python3.10/site-packages (from black) (8.1.7)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /opt/conda/lib/python3.10/site-packages (from black) (1.0.0)
# Collecting packaging
#   Downloading packaging-24.0-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.5/53.5 kB 4.6 MB/s eta 0:00:00
# Collecting pathspec>=0.9.0 (from black)
#   Downloading pathspec-0.12.1-py3-none-any.whl (31 kB)
# Requirement already satisfied: platformdirs>=2 in /opt/conda/lib/python3.10/site-packages (from black) (3.10.0)
# Requirement already satisfied: tomli>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from black) (2.0.1)
# Requirement already satisfied: typing-extensions>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from black) (4.6.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard) (0.2.7)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard) (4.9)
# Requirement already satisfied: six>=1.9.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard) (1.16.0)
# Requirement already satisfied: urllib3<2.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard) (1.26.15)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard) (2.1.3)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/conda/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard) (3.2.2)
# Building wheels for collected packages: fvcore, antlr4-python3-runtime
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61405 sha256=145db92aa0738c674ee576b97c96ae569b7183111f4b013dc54c81b5cd299eeb
#   Stored in directory: /root/.cache/pip/wheels/01/c0/af/77c1cf53a1be9e42a52b48e5af2169d40ec2e89f7362489dd0
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=9354fc7b8e722f2318b58a17d2d45d682656d42dca05c49724ce6c61b6523723
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
# Successfully built fvcore antlr4-python3-runtime
# Installing collected packages: antlr4-python3-runtime, yacs, portalocker, pathspec, packaging, omegaconf, iopath, hydra-core, black, pycocotools, fvcore
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.3
#     Uninstalling packaging-21.3:
#       Successfully uninstalled packaging-21.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# cuml 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# dask-cudf 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# cudf 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.0.2 which is incompatible.
# cudf 23.8.0 requires protobuf<5,>=4.21, but you have protobuf 3.20.3 which is incompatible.
# cuml 23.8.0 requires dask==2023.7.1, but you have dask 2023.9.0 which is incompatible.
# dask 2023.9.0 requires pyyaml>=5.3.1, but you have pyyaml 5.1 which is incompatible.
# dask-cuda 23.8.0 requires dask==2023.7.1, but you have dask 2023.9.0 which is incompatible.
# dask-cuda 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.0.2 which is incompatible.
# dask-cudf 23.8.0 requires dask==2023.7.1, but you have dask 2023.9.0 which is incompatible.
# dask-cudf 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.0.2 which is incompatible.
# distributed 2023.7.1 requires dask==2023.7.1, but you have dask 2023.9.0 which is incompatible.
# distributed 2023.7.1 requires pyyaml>=5.3.1, but you have pyyaml 5.1 which is incompatible.
# google-cloud-bigquery 2.34.4 requires packaging<22.0dev,>=14.3, but you have packaging 24.0 which is incompatible.
# jupyterlab-lsp 4.2.0 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# momepy 0.6.0 requires shapely>=2, but you have shapely 1.8.5.post1 which is incompatible.
# pymc3 3.11.5 requires numpy<1.22.2,>=1.15.0, but you have numpy 1.23.5 which is incompatible.
# pymc3 3.11.5 requires scipy<1.8.0,>=1.7.3, but you have scipy 1.11.2 which is incompatible.
# pytorch-lightning 2.0.8 requires PyYAML>=5.4, but you have pyyaml 5.1 which is incompatible.
# raft-dask 23.8.0 requires dask==2023.7.1, but you have dask 2023.9.0 which is incompatible.
# ydata-profiling 4.3.1 requires scipy<1.11,>=1.4.1, but you have scipy 1.11.2 which is incompatible.
# Successfully installed antlr4-python3-runtime-4.9.3 black-24.4.2 fvcore-0.1.5.post20221221 hydra-core-1.3.2 iopath-0.1.9 omegaconf-2.3.0 packaging-24.0 pathspec-0.12.1 portalocker-2.8.2 pycocotools-2.0.7 yacs-0.1.8

# %%
# Importing dependencies

import torch, detectron2
from detectron2.utils.logger import setup_logger
setup_logger()
print("detectron2 version:", detectron2.__version__)

import numpy as np
import os, json, cv2, random
from IPython import display
import PIL
import matplotlib.pyplot as plt

# importing detectron2 utilities
from detectron2 import model_zoo
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog, DatasetCatalog


SEED = 10
THRESHOLD = 0.8
# Out:
# detectron2 version: 0.6

# %%
# Creating coco instances

from detectron2.data.datasets import register_coco_instances
from detectron2.structures import BoxMode

    
register_coco_instances(f"tomato_dataset_train", {},
                        f"/kaggle/input/tomatod/annotations/tomatOD_train.json",
                        f"/kaggle/input/tomatod/images/train")

register_coco_instances(f"tomato_dataset_test", {},
                        f"/kaggle/input/tomatod/annotations/tomatOD_test.json",
                        f"/kaggle/input/tomatod/images/val")

# %%
import random
from detectron2.utils.visualizer import Visualizer

my_dataset_train_metadata = MetadataCatalog.get("tomato_dataset_train")
train_dataset_dicts = DatasetCatalog.get("tomato_dataset_train")

# A function that creates examples from the dataset
def create_random_images(dataset_dict,dataset_metadata, seed, image_scale = 0.7):
    np.random.seed(seed)
    images = np.random.permutation(dataset_dict)[:2]
    
    fig, axs = plt.subplots(1,2, figsize = (12,6), dpi = 100)
    for i in range(2):
        im = images[i]
        img_link = im['file_name']
        img_id = im['image_id']
        img = cv2.imread(img_link)
        img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
        visualizer = Visualizer(img, metadata= dataset_metadata, scale=image_scale)
        vis = visualizer.draw_dataset_dict(im)
        final_img = vis.get_image()
        
        axs[i].set_title('image id: ' + str(img_id), fontsize = 10)
        axs[i].axis('off')
        axs[i].imshow(final_img)
# Out:
# [06/08 02:59:32 d2.data.datasets.coco]: Loaded 222 images in COCO format from /kaggle/input/tomatod/annotations/tomatOD_train.json

# %%
create_random_images(train_dataset_dicts, my_dataset_train_metadata, seed = 5, image_scale = 1)

# %%
import os
import logging
import time
from detectron2.engine import DefaultTrainer, HookBase
from detectron2.config import get_cfg
from detectron2 import model_zoo
from tabulate import tabulate

# Configure logging
log_file = 'training_log.txt'
logging.basicConfig(filename=log_file, level=logging.INFO)

# Print message to console to confirm logging setup
print(f"Logging to {log_file}")

# List of learning rates to experiment with
learning_rates = [0.001, 0.005, 0.01]

# Number of iterations and runs
num_iterations = 1000
num_runs = 10

# Data structure to store results
results = []

# Custom hook to log the training progress
class LossLoggerHook(HookBase):
    def __init__(self):
        super().__init__()

    def after_step(self):
        if self.trainer.storage.iter % 20 == 0:  # Log every 20 iterations
            total_loss = self.trainer.storage.history("total_loss").latest()
            logging.info(f"iter: {self.trainer.storage.iter} total_loss: {total_loss}")
            print(f"Logged iteration {self.trainer.storage.iter}")

# Function to train with a specific learning rate
def train_with_learning_rate(lr):
    cfg = get_cfg()
    cfg.merge_from_file(model_zoo.get_config_file("COCO-Detection/rpn_R_50_FPN_1x.yaml"))
    cfg.DATASETS.TRAIN = ('tomato_dataset_train',)
    cfg.DATASETS.TEST = ()  # no metrics implemented for this dataset
    cfg.DATALOADER.NUM_WORKERS = 2
    cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-Detection/rpn_R_50_FPN_1x.yaml")
    cfg.SOLVER.IMS_PER_BATCH = 2
    cfg.SOLVER.MAX_ITER = num_iterations
    cfg.SOLVER.STEPS = []  # do not decay learning rate
    cfg.MODEL.ROI_HEADS.NUM_CLASSES = 3
    cfg.SOLVER.BASE_LR = lr  # Set learning rate

    # Implement gradient clipping correctly
    cfg.SOLVER.CLIP_GRADIENTS.ENABLED = True
    cfg.SOLVER.CLIP_GRADIENTS.CLIP_TYPE = "norm"
    cfg.SOLVER.CLIP_GRADIENTS.CLIP_VALUE = 1.0

    os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)
    trainer = DefaultTrainer(cfg)
    trainer.register_hooks([LossLoggerHook()])

    start_time = time.time()
    trainer.resume_or_load(resume=False)
    trainer.train()
    end_time = time.time()

    # Get the minimum loss over all iterations
    min_loss = min(trainer.storage.history("total_loss").values())

    return min_loss, end_time - start_time

# Run training for each learning rate
for lr in learning_rates:
    lr_results = []
    for run in range(num_runs):
        logging.info(f"Starting training with learning rate: {lr}, run: {run + 1}")
        print(f"Starting training with learning rate: {lr}, run: {run + 1}")
        min_loss, duration = train_with_learning_rate(lr)
        lr_results.append([lr, run + 1, min_loss, duration])
    results.extend(lr_results)

# Aggregate results for each learning rate
summary_results = []
for lr in learning_rates:
    lr_runs = [result for result in results if result[0] == lr]
    min_loss = min(lr_runs, key=lambda x: x[2])[2]
    total_time = sum(run[3] for run in lr_runs)
    summary_results.append([lr, min_loss, total_time])

# Tabulate the detailed results for each run
headers = ["Learning Rate", "Run", "Minimum Loss", "Duration (s)"]
print(tabulate(results, headers, floatfmt=".6f"))

# Log the detailed results to the file
logging.info(tabulate(results, headers, floatfmt=".6f"))

# Tabulate and print the summary results
summary_headers = ["Learning Rate", "Minimum Loss", "Total Time (s)"]
print(tabulate(summary_results, summary_headers, floatfmt=".6f"))

# Log the summary results to the file
logging.info(tabulate(summary_results, summary_headers, floatfmt=".6f"))

# Tabulate the detailed results for each learning rate
for lr in learning_rates:
    lr_runs = [result for result in results if result[0] == lr]
    print(f"\nDetailed results for learning rate: {lr}")
    print(tabulate(lr_runs, headers, floatfmt=".6f"))
    logging.info(f"\nDetailed results for learning rate: {lr}")
    logging.info(tabulate(lr_runs, headers, floatfmt=".6f"))
# Out:
# Logging to training_log.txt
# Starting training with learning rate: 0.001, run: 1
# [06/08 02:59:36 d2.engine.defaults]: Model:
# ProposalNetwork(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
# )
# [06/08 02:59:36 d2.data.datasets.coco]: Loaded 222 images in COCO format from /kaggle/input/tomatod/annotations/tomatOD_train.json
# [06/08 02:59:36 d2.data.build]: Removed 0 images with no usable annotations. 222 images left.
# [06/08 02:59:36 d2.data.build]: Distribution of instances among all 3 categories:
# |  category  | #instances   |  category  | #instances   |  category  | #instances   |
# |:----------:|:-------------|:----------:|:-------------|:----------:|:-------------|
# |   unripe   | 1301         | semi-ripe  | 320          | fully-ripe | 332          |
# |            |              |            |              |            |              |
# |   total    | 1953         |            |              |            |              |
# [06/08 02:59:36 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), RandomFlip()]
# [06/08 02:59:36 d2.data.build]: Using training sampler TrainingSampler
# [06/08 02:59:36 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [06/08 02:59:36 d2.data.common]: Serializing 222 elements to byte tensors and concatenating them all ...
# [06/08 02:59:36 d2.data.common]: Serialized dataset takes 0.10 MiB
# [06/08 02:59:36 d2.data.build]: Making batched data loader with batch_size=2
# [06/08 02:59:36 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from https://dl.fbaipublicfiles.com/detectron2/COCO-Detection/rpn_R_50_FPN_1x/137258492/model_final_02ce48.pkl ...
# model_final_02ce48.pkl: 110MB [00:00, 222MB/s]
# [06/08 02:59:36 d2.engine.train_loop]: Starting training from iteration 0
# /opt/conda/lib/python3.10/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /usr/local/src/pytorch/aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Logged iteration 0
# [06/08 02:59:43 d2.utils.events]:  eta: 0:03:32  iter: 19  total_loss: 0.1607  loss_rpn_cls: 0.1039  loss_rpn_loc: 0.06023    time: 0.2215  last_time: 0.2294  data_time: 0.0418  last_data_time: 0.0553   lr: 1.9981e-05  max_mem: 1485M
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Logged iteration 20
# [06/08 02:59:56 d2.utils.events]:  eta: 0:03:28  iter: 39  total_loss: 0.1277  loss_rpn_cls: 0.07708  loss_rpn_loc: 0.04643    time: 0.2184  last_time: 0.1939  data_time: 0.0350  last_data_time: 0.0328   lr: 3.9961e-05  max_mem: 1485M
# Logged iteration 40
# [06/08 03:00:01 d2.utils.events]:  eta: 0:03:25  iter: 59  total_loss: 0.1128  loss_rpn_cls: 0.06645  loss_rpn_loc: 0.04637    time: 0.2222  last_time: 0.2401  data_time: 0.0467  last_data_time: 0.0581   lr: 5.9941e-05  max_mem: 1486M
# Logged iteration 60
# [06/08 03:00:05 d2.utils.events]:  eta: 0:03:19  iter: 79  total_loss: 0.09325  loss_rpn_cls: 0.04667  loss_rpn_loc: 0.04059    time: 0.2202  last_time: 0.2062  data_time: 0.0312  last_data_time: 0.0046   lr: 7.9921e-05  max_mem: 1486M
# Logged iteration 80
# [06/08 03:00:09 d2.utils.events]:  eta: 0:03:15  iter: 99  total_loss: 0.06133  loss_rpn_cls: 0.0324  loss_rpn_loc: 0.03145    time: 0.2194  last_time: 0.1740  data_time: 0.0387  last_data_time: 0.0074   lr: 9.9901e-05  max_mem: 1486M
# Logged iteration 100
# [06/08 03:00:14 d2.utils.events]:  eta: 0:03:12  iter: 119  total_loss: 0.07502  loss_rpn_cls: 0.03211  loss_rpn_loc: 0.04136    time: 0.2198  last_time: 0.1764  data_time: 0.0439  last_data_time: 0.0070   lr: 0.00011988  max_mem: 1486M
# Logged iteration 120
# [06/08 03:00:18 d2.utils.events]:  eta: 0:03:05  iter: 139  total_loss: 0.06711  loss_rpn_cls: 0.02587  loss_rpn_loc: 0.04132    time: 0.2177  last_time: 0.2067  data_time: 0.0226  last_data_time: 0.0382   lr: 0.00013986  max_mem: 1486M
# Logged iteration 140
# [06/08 03:00:22 d2.utils.events]:  eta: 0:03:00  iter: 159  total_loss: 0.07148  loss_rpn_cls: 0.02577  loss_rpn_loc: 0.04522    time: 0.2170  last_time: 0.1981  data_time: 0.0297  last_data_time: 0.0151   lr: 0.00015984  max_mem: 1486M
# Logged iteration 160
# [06/08 03:00:26 d2.utils.events]:  eta: 0:02:56  iter: 179  total_loss: 0.07223  loss_rpn_cls: 0.02704  loss_rpn_loc: 0.03735    time: 0.2169  last_time: 0.2349  data_time: 0.0288  last_data_time: 0.0498   lr: 0.00017982  max_mem: 1486M
# Logged iteration 180
# [06/08 03:00:31 d2.utils.events]:  eta: 0:02:51  iter: 199  total_loss: 0.06239  loss_rpn_cls: 0.02282  loss_rpn_loc: 0.03899    time: 0.2164  last_time: 0.2558  data_time: 0.0277  last_data_time: 0.0550   lr: 0.0001998  max_mem: 1486M
# Logged iteration 200
# [06/08 03:00:35 d2.utils.events]:  eta: 0:02:46  iter: 219  total_loss: 0.05478  loss_rpn_cls: 0.0175  loss_rpn_loc: 0.03492    time: 0.2169  last_time: 0.2201  data_time: 0.0342  last_data_time: 0.0143   lr: 0.00021978  max_mem: 1486M
# Logged iteration 220
# [06/08 03:00:39 d2.utils.events]:  eta: 0:02:41  iter: 239  total_loss: 0.05173  loss_rpn_cls: 0.01762  loss_rpn_loc: 0.03238    time: 0.2167  last_time: 0.2172  data_time: 0.0364  last_data_time: 0.0619   lr: 0.00023976  max_mem: 1486M
# Logged iteration 240
# [06/08 03:00:44 d2.utils.events]:  eta: 0:02:37  iter: 259  total_loss: 0.05126  loss_rpn_cls: 0.01403  loss_rpn_loc: 0.03453    time: 0.2162  last_time: 0.2591  data_time: 0.0316  last_data_time: 0.0622   lr: 0.00025974  max_mem: 1486M
# Logged iteration 260
# [06/08 03:00:48 d2.utils.events]:  eta: 0:02:33  iter: 279  total_loss: 0.04915  loss_rpn_cls: 0.01659  loss_rpn_loc: 0.02937    time: 0.2161  last_time: 0.2347  data_time: 0.0395  last_data_time: 0.0592   lr: 0.00027972  max_mem: 1486M
# Logged iteration 280
# [06/08 03:00:52 d2.utils.events]:  eta: 0:02:28  iter: 299  total_loss: 0.05404  loss_rpn_cls: 0.01503  loss_rpn_loc: 0.0402    time: 0.2155  last_time: 0.2044  data_time: 0.0293  last_data_time: 0.0373   lr: 0.0002997  max_mem: 1486M
# Logged iteration 300
# [06/08 03:00:56 d2.utils.events]:  eta: 0:02:24  iter: 319  total_loss: 0.0604  loss_rpn_cls: 0.01904  loss_rpn_loc: 0.03964    time: 0.2150  last_time: 0.1834  data_time: 0.0256  last_data_time: 0.0196   lr: 0.00031968  max_mem: 1486M
# Logged iteration 320
# [06/08 03:01:00 d2.utils.events]:  eta: 0:02:19  iter: 339  total_loss: 0.04658  loss_rpn_cls: 0.01176  loss_rpn_loc: 0.03662    time: 0.2146  last_time: 0.2215  data_time: 0.0233  last_data_time: 0.0405   lr: 0.00033966  max_mem: 1486M
# Logged iteration 340
# [06/08 03:01:05 d2.utils.events]:  eta: 0:02:15  iter: 359  total_loss: 0.047  loss_rpn_cls: 0.01082  loss_rpn_loc: 0.03645    time: 0.2151  last_time: 0.2112  data_time: 0.0353  last_data_time: 0.0259   lr: 0.00035964  max_mem: 1486M
# Logged iteration 360
# [06/08 03:01:09 d2.utils.events]:  eta: 0:02:11  iter: 379  total_loss: 0.05217  loss_rpn_cls: 0.01029  loss_rpn_loc: 0.03705    time: 0.2147  last_time: 0.2205  data_time: 0.0305  last_data_time: 0.0517   lr: 0.00037962  max_mem: 1486M
# Logged iteration 380
# [06/08 03:01:13 d2.utils.events]:  eta: 0:02:07  iter: 399  total_loss: 0.04564  loss_rpn_cls: 0.01105  loss_rpn_loc: 0.03355    time: 0.2147  last_time: 0.2455  data_time: 0.0381  last_data_time: 0.0562   lr: 0.0003996  max_mem: 1486M
# Logged iteration 400
# [06/08 03:01:18 d2.utils.events]:  eta: 0:02:02  iter: 419  total_loss: 0.04559  loss_rpn_cls: 0.01359  loss_rpn_loc: 0.03294    time: 0.2147  last_time: 0.2093  data_time: 0.0309  last_data_time: 0.0054   lr: 0.00041958  max_mem: 1486M
# Logged iteration 420
# [06/08 03:01:22 d2.utils.events]:  eta: 0:01:58  iter: 439  total_loss: 0.05926  loss_rpn_cls: 0.0162  loss_rpn_loc: 0.04557    time: 0.2144  last_time: 0.1518  data_time: 0.0283  last_data_time: 0.0044   lr: 0.00043956  max_mem: 1486M
# Logged iteration 440
# [06/08 03:01:26 d2.utils.events]:  eta: 0:01:54  iter: 459  total_loss: 0.05031  loss_rpn_cls: 0.01199  loss_rpn_loc: 0.03448    time: 0.2144  last_time: 0.1895  data_time: 0.0351  last_data_time: 0.0191   lr: 0.00045954  max_mem: 1486M
# Logged iteration 460
# [06/08 03:01:30 d2.utils.events]:  eta: 0:01:50  iter: 479  total_loss: 0.03613  loss_rpn_cls: 0.007131  loss_rpn_loc: 0.03134    time: 0.2141  last_time: 0.2106  data_time: 0.0295  last_data_time: 0.0449   lr: 0.00047952  max_mem: 1486M
# Logged iteration 480
# [06/08 03:01:35 d2.utils.events]:  eta: 0:01:45  iter: 499  total_loss: 0.04848  loss_rpn_cls: 0.006914  loss_rpn_loc: 0.04399    time: 0.2146  last_time: 0.2663  data_time: 0.0411  last_data_time: 0.0612   lr: 0.0004995  max_mem: 1486M
# Logged iteration 500
# [06/08 03:01:39 d2.utils.events]:  eta: 0:01:41  iter: 519  total_loss: 0.0528  loss_rpn_cls: 0.01057  loss_rpn_loc: 0.0338    time: 0.2145  last_time: 0.2418  data_time: 0.0344  last_data_time: 0.0485   lr: 0.00051948  max_mem: 1486M
# Logged iteration 520
# [06/08 03:01:43 d2.utils.events]:  eta: 0:01:37  iter: 539  total_loss: 0.04921  loss_rpn_cls: 0.008592  loss_rpn_loc: 0.03459    time: 0.2143  last_time: 0.2125  data_time: 0.0324  last_data_time: 0.0317   lr: 0.00053946  max_mem: 1486M
# Logged iteration 540
# [06/08 03:01:48 d2.utils.events]:  eta: 0:01:33  iter: 559  total_loss: 0.04652  loss_rpn_cls: 0.008357  loss_rpn_loc: 0.03883    time: 0.2142  last_time: 0.2346  data_time: 0.0312  last_data_time: 0.0651   lr: 0.00055944  max_mem: 1486M
# Logged iteration 560
# [06/08 03:01:52 d2.utils.events]:  eta: 0:01:29  iter: 579  total_loss: 0.05901  loss_rpn_cls: 0.01599  loss_rpn_loc: 0.041    time: 0.2143  last_time: 0.2085  data_time: 0.0320  last_data_time: 0.0399   lr: 0.00057942  max_mem: 1486M
# Logged iteration 580
# [06/08 03:01:56 d2.utils.events]:  eta: 0:01:24  iter: 599  total_loss: 0.04086  loss_rpn_cls: 0.009804  loss_rpn_loc: 0.0323    time: 0.2147  last_time: 0.2595  data_time: 0.0401  last_data_time: 0.0692   lr: 0.0005994  max_mem: 1486M
# Logged iteration 600
# [06/08 03:02:01 d2.utils.events]:  eta: 0:01:20  iter: 619  total_loss: 0.04539  loss_rpn_cls: 0.007686  loss_rpn_loc: 0.03935    time: 0.2148  last_time: 0.2018  data_time: 0.0410  last_data_time: 0.0328   lr: 0.00061938  max_mem: 1486M
# Logged iteration 620
# [06/08 03:02:05 d2.utils.events]:  eta: 0:01:16  iter: 639  total_loss: 0.0457  loss_rpn_cls: 0.008715  loss_rpn_loc: 0.03729    time: 0.2148  last_time: 0.2357  data_time: 0.0354  last_data_time: 0.0444   lr: 0.00063936  max_mem: 1486M
# Logged iteration 640
# [06/08 03:02:10 d2.utils.events]:  eta: 0:01:12  iter: 659  total_loss: 0.03737  loss_rpn_cls: 0.005948  loss_rpn_loc: 0.02951    time: 0.2149  last_time: 0.2205  data_time: 0.0330  last_data_time: 0.0200   lr: 0.00065934  max_mem: 1486M
# Logged iteration 660
# [06/08 03:02:14 d2.utils.events]:  eta: 0:01:07  iter: 679  total_loss: 0.03948  loss_rpn_cls: 0.006757  loss_rpn_loc: 0.03296    time: 0.2149  last_time: 0.2084  data_time: 0.0389  last_data_time: 0.0091   lr: 0.00067932  max_mem: 1486M
# Logged iteration 680
# [06/08 03:02:18 d2.utils.events]:  eta: 0:01:03  iter: 699  total_loss: 0.04544  loss_rpn_cls: 0.005424  loss_rpn_loc: 0.03911    time: 0.2147  last_time: 0.2379  data_time: 0.0223  last_data_time: 0.0401   lr: 0.0006993  max_mem: 1487M
# Logged iteration 700
# [06/08 03:02:22 d2.utils.events]:  eta: 0:00:59  iter: 719  total_loss: 0.03495  loss_rpn_cls: 0.007792  loss_rpn_loc: 0.02798    time: 0.2148  last_time: 0.2066  data_time: 0.0420  last_data_time: 0.0340   lr: 0.00071928  max_mem: 1487M
# Logged iteration 720
# [06/08 03:02:27 d2.utils.events]:  eta: 0:00:55  iter: 739  total_loss: 0.04718  loss_rpn_cls: 0.008127  loss_rpn_loc: 0.03906    time: 0.2147  last_time: 0.2392  data_time: 0.0294  last_data_time: 0.0571   lr: 0.00073926  max_mem: 1487M
# Logged iteration 740
# [06/08 03:02:31 d2.utils.events]:  eta: 0:00:51  iter: 759  total_loss: 0.04484  loss_rpn_cls: 0.006869  loss_rpn_loc: 0.03636    time: 0.2147  last_time: 0.2332  data_time: 0.0325  last_data_time: 0.0365   lr: 0.00075924  max_mem: 1487M
# Logged iteration 760
# [06/08 03:02:35 d2.utils.events]:  eta: 0:00:46  iter: 779  total_loss: 0.03953  loss_rpn_cls: 0.005273  loss_rpn_loc: 0.03346    time: 0.2147  last_time: 0.2420  data_time: 0.0387  last_data_time: 0.0591   lr: 0.00077922  max_mem: 1487M
# Logged iteration 780
# [06/08 03:02:40 d2.utils.events]:  eta: 0:00:42  iter: 799  total_loss: 0.0379  loss_rpn_cls: 0.006928  loss_rpn_loc: 0.03034    time: 0.2150  last_time: 0.2229  data_time: 0.0412  last_data_time: 0.0546   lr: 0.0007992  max_mem: 1489M
# Logged iteration 800
# [06/08 03:02:44 d2.utils.events]:  eta: 0:00:38  iter: 819  total_loss: 0.04516  loss_rpn_cls: 0.005862  loss_rpn_loc: 0.03745    time: 0.2149  last_time: 0.1892  data_time: 0.0322  last_data_time: 0.0175   lr: 0.00081918  max_mem: 1489M
# Logged iteration 820
# [06/08 03:02:48 d2.utils.events]:  eta: 0:00:34  iter: 839  total_loss: 0.04299  loss_rpn_cls: 0.005232  loss_rpn_loc: 0.03612    time: 0.2147  last_time: 0.2496  data_time: 0.0293  last_data_time: 0.0610   lr: 0.00083916  max_mem: 1489M
# Logged iteration 840
# [06/08 03:02:52 d2.utils.events]:  eta: 0:00:29  iter: 859  total_loss: 0.03735  loss_rpn_cls: 0.005784  loss_rpn_loc: 0.0314    time: 0.2145  last_time: 0.2187  data_time: 0.0329  last_data_time: 0.0526   lr: 0.00085914  max_mem: 1489M
# Logged iteration 860
# [06/08 03:02:57 d2.utils.events]:  eta: 0:00:25  iter: 879  total_loss: 0.04139  loss_rpn_cls: 0.006176  loss_rpn_loc: 0.03369    time: 0.2145  last_time: 0.2399  data_time: 0.0372  last_data_time: 0.0416   lr: 0.00087912  max_mem: 1489M
# Logged iteration 880
# [06/08 03:03:01 d2.utils.events]:  eta: 0:00:21  iter: 899  total_loss: 0.04444  loss_rpn_cls: 0.007673  loss_rpn_loc: 0.0359    time: 0.2144  last_time: 0.1926  data_time: 0.0251  last_data_time: 0.0055   lr: 0.0008991  max_mem: 1489M
# Logged iteration 900
# [06/08 03:03:05 d2.utils.events]:  eta: 0:00:16  iter: 919  total_loss: 0.03415  loss_rpn_cls: 0.005459  loss_rpn_loc: 0.02605    time: 0.2143  last_time: 0.1977  data_time: 0.0269  last_data_time: 0.0206   lr: 0.00091908  max_mem: 1489M
# Logged iteration 920
# [06/08 03:03:09 d2.utils.events]:  eta: 0:00:12  iter: 939  total_loss: 0.04059  loss_rpn_cls: 0.004207  loss_rpn_loc: 0.03544    time: 0.2141  last_time: 0.2463  data_time: 0.0249  last_data_time: 0.0376   lr: 0.00093906  max_mem: 1489M
# Logged iteration 940
# [06/08 03:03:14 d2.utils.events]:  eta: 0:00:08  iter: 959  total_loss: 0.03136  loss_rpn_cls: 0.005063  loss_rpn_loc: 0.0277    time: 0.2143  last_time: 0.2280  data_time: 0.0369  last_data_time: 0.0511   lr: 0.00095904  max_mem: 1489M
# Logged iteration 960
# [06/08 03:03:18 d2.utils.events]:  eta: 0:00:04  iter: 979  total_loss: 0.04085  loss_rpn_cls: 0.005283  loss_rpn_loc: 0.03547    time: 0.2143  last_time: 0.1870  data_time: 0.0311  last_data_time: 0.0067   lr: 0.00097902  max_mem: 1489M
# Logged iteration 980
# [06/08 03:03:23 d2.utils.events]:  eta: 0:00:00  iter: 999  total_loss: 0.04219  loss_rpn_cls: 0.004337  loss_rpn_loc: 0.03741    time: 0.2143  last_time: 0.2070  data_time: 0.0332  last_data_time: 0.0267   lr: 0.000999  max_mem: 1489M
# [06/08 03:03:23 d2.engine.hooks]: Overall training speed: 998 iterations in 0:03:33 (0.2143 s / it)
# [06/08 03:03:23 d2.engine.hooks]: Total training time: 0:03:43 (0:00:09 on hooks)
# Starting training with learning rate: 0.001, run: 2
# [06/08 03:03:23 d2.engine.defaults]: Model:
# ProposalNetwork(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
# )
# [06/08 03:03:23 d2.data.datasets.coco]: Loaded 222 images in COCO format from /kaggle/input/tomatod/annotations/tomatOD_train.json
# [06/08 03:03:23 d2.data.build]: Removed 0 images with no usable annotations. 222 images left.
# [06/08 03:03:23 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), RandomFlip()]
# [06/08 03:03:23 d2.data.build]: Using training sampler TrainingSampler
# [06/08 03:03:23 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [06/08 03:03:23 d2.data.common]: Serializing 222 elements to byte tensors and concatenating them all ...
# [06/08 03:03:23 d2.data.common]: Serialized dataset takes 0.10 MiB
# [06/08 03:03:23 d2.data.build]: Making batched data loader with batch_size=2
# [06/08 03:03:23 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from https://dl.fbaipublicfiles.com/detectron2/COCO-Detection/rpn_R_50_FPN_1x/137258492/model_final_02ce48.pkl ...
# [06/08 03:03:23 d2.engine.train_loop]: Starting training from iteration 0
# Logged iteration 0
# [06/08 03:03:28 d2.utils.events]:  eta: 0:03:26  iter: 19  total_loss: 0.1324  loss_rpn_cls: 0.08881  loss_rpn_loc: 0.04321    time: 0.2108  last_time: 0.2391  data_time: 0.0487  last_data_time: 0.0460   lr: 1.9981e-05  max_mem: 1489M
# Logged iteration 20
# [06/08 03:03:32 d2.utils.events]:  eta: 0:03:23  iter: 39  total_loss: 0.1415  loss_rpn_cls: 0.08216  loss_rpn_loc: 0.04807    time: 0.2125  last_time: 0.2116  data_time: 0.0351  last_data_time: 0.0124   lr: 3.9961e-05  max_mem: 1489M
# Logged iteration 40
# [06/08 03:03:36 d2.utils.events]:  eta: 0:03:18  iter: 59  total_loss: 0.1102  loss_rpn_cls: 0.06166  loss_rpn_loc: 0.04564    time: 0.2116  last_time: 0.2087  data_time: 0.0322  last_data_time: 0.0250   lr: 5.9941e-05  max_mem: 1489M
# Logged iteration 60
# [06/08 03:03:41 d2.utils.events]:  eta: 0:03:16  iter: 79  total_loss: 0.09917  loss_rpn_cls: 0.05408  loss_rpn_loc: 0.04683    time: 0.2144  last_time: 0.2238  data_time: 0.0407  last_data_time: 0.0430   lr: 7.9921e-05  max_mem: 1489M
# Logged iteration 80
# [06/08 03:03:46 d2.utils.events]:  eta: 0:03:11  iter: 99  total_loss: 0.0861  loss_rpn_cls: 0.04229  loss_rpn_loc: 0.04202    time: 0.2161  last_time: 0.1778  data_time: 0.0365  last_data_time: 0.0058   lr: 9.9901e-05  max_mem: 1489M
# Logged iteration 100
# [06/08 03:03:50 d2.utils.events]:  eta: 0:03:10  iter: 119  total_loss: 0.0905  loss_rpn_cls: 0.03744  loss_rpn_loc: 0.05091    time: 0.2170  last_time: 0.2248  data_time: 0.0374  last_data_time: 0.0429   lr: 0.00011988  max_mem: 1489M
# Logged iteration 120
# [06/08 03:03:54 d2.utils.events]:  eta: 0:03:05  iter: 139  total_loss: 0.06609  loss_rpn_cls: 0.02616  loss_rpn_loc: 0.04042    time: 0.2166  last_time: 0.1902  data_time: 0.0355  last_data_time: 0.0094   lr: 0.00013986  max_mem: 1489M
# Logged iteration 140
# [06/08 03:03:59 d2.utils.events]:  eta: 0:03:01  iter: 159  total_loss: 0.06226  loss_rpn_cls: 0.02515  loss_rpn_loc: 0.04012    time: 0.2166  last_time: 0.1802  data_time: 0.0394  last_data_time: 0.0203   lr: 0.00015984  max_mem: 1489M
# Logged iteration 160
# [06/08 03:04:03 d2.utils.events]:  eta: 0:02:56  iter: 179  total_loss: 0.06792  loss_rpn_cls: 0.02278  loss_rpn_loc: 0.04163    time: 0.2156  last_time: 0.2248  data_time: 0.0271  last_data_time: 0.0370   lr: 0.00017982  max_mem: 1489M
# Logged iteration 180
# [06/08 03:04:07 d2.utils.events]:  eta: 0:02:51  iter: 199  total_loss: 0.05973  loss_rpn_cls: 0.02205  loss_rpn_loc: 0.0345    time: 0.2151  last_time: 0.2366  data_time: 0.0306  last_data_time: 0.0604   lr: 0.0001998  max_mem: 1489M
# Logged iteration 200
# [06/08 03:04:11 d2.utils.events]:  eta: 0:02:46  iter: 219  total_loss: 0.06079  loss_rpn_cls: 0.01719  loss_rpn_loc: 0.03948    time: 0.2146  last_time: 0.2132  data_time: 0.0226  last_data_time: 0.0156   lr: 0.00021978  max_mem: 1489M
# Logged iteration 220
# [06/08 03:04:16 d2.utils.events]:  eta: 0:02:43  iter: 239  total_loss: 0.0594  loss_rpn_cls: 0.01726  loss_rpn_loc: 0.04347    time: 0.2159  last_time: 0.2075  data_time: 0.0448  last_data_time: 0.0105   lr: 0.00023976  max_mem: 1489M
# Logged iteration 240
# [06/08 03:04:20 d2.utils.events]:  eta: 0:02:38  iter: 259  total_loss: 0.05494  loss_rpn_cls: 0.01373  loss_rpn_loc: 0.04031    time: 0.2157  last_time: 0.2416  data_time: 0.0351  last_data_time: 0.0437   lr: 0.00025974  max_mem: 1489M
# Logged iteration 260
# [06/08 03:04:24 d2.utils.events]:  eta: 0:02:33  iter: 279  total_loss: 0.0593  loss_rpn_cls: 0.01735  loss_rpn_loc: 0.04027    time: 0.2152  last_time: 0.2009  data_time: 0.0314  last_data_time: 0.0077   lr: 0.00027972  max_mem: 1489M
# Logged iteration 280
# [06/08 03:04:29 d2.utils.events]:  eta: 0:02:29  iter: 299  total_loss: 0.06237  loss_rpn_cls: 0.01846  loss_rpn_loc: 0.04533    time: 0.2150  last_time: 0.2190  data_time: 0.0289  last_data_time: 0.0234   lr: 0.0002997  max_mem: 1489M
# Logged iteration 300
# [06/08 03:04:33 d2.utils.events]:  eta: 0:02:24  iter: 319  total_loss: 0.05294  loss_rpn_cls: 0.01313  loss_rpn_loc: 0.03332    time: 0.2150  last_time: 0.2169  data_time: 0.0287  last_data_time: 0.0406   lr: 0.00031968  max_mem: 1489M
# Logged iteration 320
# [06/08 03:04:37 d2.utils.events]:  eta: 0:02:20  iter: 339  total_loss: 0.04725  loss_rpn_cls: 0.01016  loss_rpn_loc: 0.03799    time: 0.2144  last_time: 0.2116  data_time: 0.0260  last_data_time: 0.0337   lr: 0.00033966  max_mem: 1489M
# Logged iteration 340
# [06/08 03:04:41 d2.utils.events]:  eta: 0:02:16  iter: 359  total_loss: 0.05024  loss_rpn_cls: 0.01234  loss_rpn_loc: 0.03889    time: 0.2143  last_time: 0.1795  data_time: 0.0288  last_data_time: 0.0054   lr: 0.00035964  max_mem: 1489M
# Logged iteration 360
# [06/08 03:04:46 d2.utils.events]:  eta: 0:02:12  iter: 379  total_loss: 0.05219  loss_rpn_cls: 0.01525  loss_rpn_loc: 0.03659    time: 0.2148  last_time: 0.1851  data_time: 0.0409  last_data_time: 0.0203   lr: 0.00037962  max_mem: 1489M
# Logged iteration 380
# [06/08 03:04:50 d2.utils.events]:  eta: 0:02:07  iter: 399  total_loss: 0.06013  loss_rpn_cls: 0.01322  loss_rpn_loc: 0.04059    time: 0.2145  last_time: 0.2052  data_time: 0.0296  last_data_time: 0.0281   lr: 0.0003996  max_mem: 1489M
# Logged iteration 400
# [06/08 03:04:54 d2.utils.events]:  eta: 0:02:03  iter: 419  total_loss: 0.04595  loss_rpn_cls: 0.01142  loss_rpn_loc: 0.03206    time: 0.2140  last_time: 0.1949  data_time: 0.0304  last_data_time: 0.0059   lr: 0.00041958  max_mem: 1489M
# Logged iteration 420
# [06/08 03:04:58 d2.utils.events]:  eta: 0:01:58  iter: 439  total_loss: 0.04529  loss_rpn_cls: 0.009939  loss_rpn_loc: 0.03453    time: 0.2138  last_time: 0.2353  data_time: 0.0338  last_data_time: 0.0377   lr: 0.00043956  max_mem: 1489M
# Logged iteration 440
# [06/08 03:05:03 d2.utils.events]:  eta: 0:01:54  iter: 459  total_loss: 0.04632  loss_rpn_cls: 0.01065  loss_rpn_loc: 0.0354    time: 0.2139  last_time: 0.2618  data_time: 0.0345  last_data_time: 0.0734   lr: 0.00045954  max_mem: 1489M
# Logged iteration 460
# [06/08 03:05:07 d2.utils.events]:  eta: 0:01:50  iter: 479  total_loss: 0.04332  loss_rpn_cls: 0.006835  loss_rpn_loc: 0.03612    time: 0.2139  last_time: 0.2254  data_time: 0.0306  last_data_time: 0.0254   lr: 0.00047952  max_mem: 1489M
# Logged iteration 480
# [06/08 03:05:11 d2.utils.events]:  eta: 0:01:45  iter: 499  total_loss: 0.05371  loss_rpn_cls: 0.009052  loss_rpn_loc: 0.04197    time: 0.2136  last_time: 0.2214  data_time: 0.0291  last_data_time: 0.0747   lr: 0.0004995  max_mem: 1489M
# Logged iteration 500
# [06/08 03:05:16 d2.utils.events]:  eta: 0:01:41  iter: 519  total_loss: 0.04552  loss_rpn_cls: 0.01173  loss_rpn_loc: 0.03518    time: 0.2139  last_time: 0.2392  data_time: 0.0367  last_data_time: 0.0388   lr: 0.00051948  max_mem: 1489M
# Logged iteration 520
# [06/08 03:05:20 d2.utils.events]:  eta: 0:01:37  iter: 539  total_loss: 0.04172  loss_rpn_cls: 0.007119  loss_rpn_loc: 0.03531    time: 0.2140  last_time: 0.2273  data_time: 0.0310  last_data_time: 0.0415   lr: 0.00053946  max_mem: 1489M
# Logged iteration 540
# [06/08 03:05:24 d2.utils.events]:  eta: 0:01:33  iter: 559  total_loss: 0.04558  loss_rpn_cls: 0.01201  loss_rpn_loc: 0.03611    time: 0.2139  last_time: 0.2064  data_time: 0.0263  last_data_time: 0.0076   lr: 0.00055944  max_mem: 1489M
# Logged iteration 560
# [06/08 03:05:28 d2.utils.events]:  eta: 0:01:28  iter: 579  total_loss: 0.04738  loss_rpn_cls: 0.0121  loss_rpn_loc: 0.03571    time: 0.2135  last_time: 0.2360  data_time: 0.0245  last_data_time: 0.0606   lr: 0.00057942  max_mem: 1489M
# Logged iteration 580
# [06/08 03:05:32 d2.utils.events]:  eta: 0:01:24  iter: 599  total_loss: 0.04845  loss_rpn_cls: 0.009942  loss_rpn_loc: 0.03737    time: 0.2134  last_time: 0.2150  data_time: 0.0284  last_data_time: 0.0303   lr: 0.0005994  max_mem: 1489M
# Logged iteration 600
# [06/08 03:05:37 d2.utils.events]:  eta: 0:01:20  iter: 619  total_loss: 0.03388  loss_rpn_cls: 0.006186  loss_rpn_loc: 0.03031    time: 0.2134  last_time: 0.2289  data_time: 0.0358  last_data_time: 0.0603   lr: 0.00061938  max_mem: 1489M
# Logged iteration 620
# [06/08 03:05:41 d2.utils.events]:  eta: 0:01:16  iter: 639  total_loss: 0.04177  loss_rpn_cls: 0.005609  loss_rpn_loc: 0.0321    time: 0.2134  last_time: 0.2192  data_time: 0.0316  last_data_time: 0.0062   lr: 0.00063936  max_mem: 1489M
# Logged iteration 640
# ...
# Logged iteration 180
# [06/08 04:44:32 d2.utils.events]:  eta: 0:02:53  iter: 199  total_loss: 0.04703  loss_rpn_cls: 0.008237  loss_rpn_loc: 0.03689    time: 0.2172  last_time: 0.2417  data_time: 0.0432  last_data_time: 0.0520   lr: 0.001998  max_mem: 1489M
# Logged iteration 200
# [06/08 04:44:36 d2.utils.events]:  eta: 0:02:47  iter: 219  total_loss: 0.04553  loss_rpn_cls: 0.005905  loss_rpn_loc: 0.03969    time: 0.2169  last_time: 0.1793  data_time: 0.0340  last_data_time: 0.0329   lr: 0.0021978  max_mem: 1489M
# Logged iteration 220
# [06/08 04:44:41 d2.utils.events]:  eta: 0:02:43  iter: 239  total_loss: 0.04816  loss_rpn_cls: 0.01009  loss_rpn_loc: 0.04014    time: 0.2177  last_time: 0.1997  data_time: 0.0397  last_data_time: 0.0213   lr: 0.0023976  max_mem: 1489M
# Logged iteration 240
# [06/08 04:44:45 d2.utils.events]:  eta: 0:02:40  iter: 259  total_loss: 0.04275  loss_rpn_cls: 0.00547  loss_rpn_loc: 0.03677    time: 0.2176  last_time: 0.2598  data_time: 0.0322  last_data_time: 0.0599   lr: 0.0025974  max_mem: 1489M
# Logged iteration 260
# [06/08 04:44:49 d2.utils.events]:  eta: 0:02:35  iter: 279  total_loss: 0.04771  loss_rpn_cls: 0.005671  loss_rpn_loc: 0.03947    time: 0.2172  last_time: 0.2350  data_time: 0.0344  last_data_time: 0.0588   lr: 0.0027972  max_mem: 1489M
# Logged iteration 280
# [06/08 04:44:54 d2.utils.events]:  eta: 0:02:31  iter: 299  total_loss: 0.03489  loss_rpn_cls: 0.007078  loss_rpn_loc: 0.02544    time: 0.2172  last_time: 0.1984  data_time: 0.0364  last_data_time: 0.0239   lr: 0.002997  max_mem: 1489M
# Logged iteration 300
# [06/08 04:44:58 d2.utils.events]:  eta: 0:02:26  iter: 319  total_loss: 0.03696  loss_rpn_cls: 0.005305  loss_rpn_loc: 0.03028    time: 0.2168  last_time: 0.1957  data_time: 0.0287  last_data_time: 0.0368   lr: 0.0031968  max_mem: 1489M
# Logged iteration 320
# [06/08 04:45:02 d2.utils.events]:  eta: 0:02:21  iter: 339  total_loss: 0.04725  loss_rpn_cls: 0.006352  loss_rpn_loc: 0.03079    time: 0.2165  last_time: 0.2244  data_time: 0.0294  last_data_time: 0.0491   lr: 0.0033966  max_mem: 1489M
# Logged iteration 340
# [06/08 04:45:07 d2.utils.events]:  eta: 0:02:17  iter: 359  total_loss: 0.04036  loss_rpn_cls: 0.007765  loss_rpn_loc: 0.03392    time: 0.2166  last_time: 0.2089  data_time: 0.0391  last_data_time: 0.0095   lr: 0.0035964  max_mem: 1489M
# Logged iteration 360
# [06/08 04:45:11 d2.utils.events]:  eta: 0:02:13  iter: 379  total_loss: 0.04548  loss_rpn_cls: 0.0111  loss_rpn_loc: 0.03452    time: 0.2171  last_time: 0.1991  data_time: 0.0451  last_data_time: 0.0250   lr: 0.0037962  max_mem: 1489M
# Logged iteration 380
# [06/08 04:45:15 d2.utils.events]:  eta: 0:02:08  iter: 399  total_loss: 0.05323  loss_rpn_cls: 0.008052  loss_rpn_loc: 0.04393    time: 0.2169  last_time: 0.2118  data_time: 0.0281  last_data_time: 0.0101   lr: 0.003996  max_mem: 1489M
# Logged iteration 400
# [06/08 04:45:19 d2.utils.events]:  eta: 0:02:03  iter: 419  total_loss: 0.04509  loss_rpn_cls: 0.005313  loss_rpn_loc: 0.03827    time: 0.2162  last_time: 0.1903  data_time: 0.0216  last_data_time: 0.0277   lr: 0.0041958  max_mem: 1489M
# Logged iteration 420
# [06/08 04:45:24 d2.utils.events]:  eta: 0:01:59  iter: 439  total_loss: 0.04244  loss_rpn_cls: 0.003195  loss_rpn_loc: 0.03286    time: 0.2163  last_time: 0.2009  data_time: 0.0307  last_data_time: 0.0062   lr: 0.0043956  max_mem: 1489M
# Logged iteration 440
# [06/08 04:45:28 d2.utils.events]:  eta: 0:01:55  iter: 459  total_loss: 0.04596  loss_rpn_cls: 0.005164  loss_rpn_loc: 0.03947    time: 0.2159  last_time: 0.2406  data_time: 0.0233  last_data_time: 0.0404   lr: 0.0045954  max_mem: 1489M
# Logged iteration 460
# [06/08 04:45:32 d2.utils.events]:  eta: 0:01:50  iter: 479  total_loss: 0.04671  loss_rpn_cls: 0.00644  loss_rpn_loc: 0.03841    time: 0.2159  last_time: 0.2255  data_time: 0.0381  last_data_time: 0.0442   lr: 0.0047952  max_mem: 1489M
# Logged iteration 480
# [06/08 04:45:36 d2.utils.events]:  eta: 0:01:46  iter: 499  total_loss: 0.04492  loss_rpn_cls: 0.005947  loss_rpn_loc: 0.03986    time: 0.2155  last_time: 0.2167  data_time: 0.0255  last_data_time: 0.0354   lr: 0.004995  max_mem: 1489M
# Logged iteration 500
# [06/08 04:45:41 d2.utils.events]:  eta: 0:01:42  iter: 519  total_loss: 0.04801  loss_rpn_cls: 0.004191  loss_rpn_loc: 0.039    time: 0.2153  last_time: 0.2306  data_time: 0.0327  last_data_time: 0.0647   lr: 0.0051948  max_mem: 1489M
# Logged iteration 520
# [06/08 04:45:45 d2.utils.events]:  eta: 0:01:38  iter: 539  total_loss: 0.03552  loss_rpn_cls: 0.005667  loss_rpn_loc: 0.02961    time: 0.2160  last_time: 0.2666  data_time: 0.0485  last_data_time: 0.0829   lr: 0.0053946  max_mem: 1489M
# Logged iteration 540
# [06/08 04:45:50 d2.utils.events]:  eta: 0:01:34  iter: 559  total_loss: 0.03328  loss_rpn_cls: 0.004788  loss_rpn_loc: 0.02786    time: 0.2161  last_time: 0.2121  data_time: 0.0389  last_data_time: 0.0217   lr: 0.0055944  max_mem: 1489M
# Logged iteration 560
# [06/08 04:45:54 d2.utils.events]:  eta: 0:01:29  iter: 579  total_loss: 0.03257  loss_rpn_cls: 0.003405  loss_rpn_loc: 0.02996    time: 0.2161  last_time: 0.1719  data_time: 0.0296  last_data_time: 0.0069   lr: 0.0057942  max_mem: 1489M
# Logged iteration 580
# [06/08 04:45:58 d2.utils.events]:  eta: 0:01:25  iter: 599  total_loss: 0.04145  loss_rpn_cls: 0.004938  loss_rpn_loc: 0.03258    time: 0.2158  last_time: 0.2471  data_time: 0.0320  last_data_time: 0.0494   lr: 0.005994  max_mem: 1489M
# Logged iteration 600
# [06/08 04:46:03 d2.utils.events]:  eta: 0:01:21  iter: 619  total_loss: 0.05254  loss_rpn_cls: 0.008203  loss_rpn_loc: 0.0403    time: 0.2156  last_time: 0.2716  data_time: 0.0292  last_data_time: 0.0711   lr: 0.0061938  max_mem: 1489M
# Logged iteration 620
# [06/08 04:46:07 d2.utils.events]:  eta: 0:01:16  iter: 639  total_loss: 0.0498  loss_rpn_cls: 0.008472  loss_rpn_loc: 0.03892    time: 0.2157  last_time: 0.2192  data_time: 0.0459  last_data_time: 0.0505   lr: 0.0063936  max_mem: 1489M
# Logged iteration 640
# [06/08 04:46:11 d2.utils.events]:  eta: 0:01:12  iter: 659  total_loss: 0.03848  loss_rpn_cls: 0.004598  loss_rpn_loc: 0.03488    time: 0.2156  last_time: 0.1898  data_time: 0.0325  last_data_time: 0.0118   lr: 0.0065934  max_mem: 1489M
# Logged iteration 660
# [06/08 04:46:16 d2.utils.events]:  eta: 0:01:08  iter: 679  total_loss: 0.04131  loss_rpn_cls: 0.004777  loss_rpn_loc: 0.03581    time: 0.2159  last_time: 0.1959  data_time: 0.0408  last_data_time: 0.0360   lr: 0.0067932  max_mem: 1489M
# Logged iteration 680
# [06/08 04:46:20 d2.utils.events]:  eta: 0:01:04  iter: 699  total_loss: 0.04418  loss_rpn_cls: 0.003587  loss_rpn_loc: 0.03907    time: 0.2158  last_time: 0.2124  data_time: 0.0311  last_data_time: 0.0144   lr: 0.006993  max_mem: 1489M
# Logged iteration 700
# [06/08 04:46:24 d2.utils.events]:  eta: 0:00:59  iter: 719  total_loss: 0.03501  loss_rpn_cls: 0.002832  loss_rpn_loc: 0.03207    time: 0.2155  last_time: 0.2174  data_time: 0.0257  last_data_time: 0.0129   lr: 0.0071928  max_mem: 1489M
# Logged iteration 720
# [06/08 04:46:28 d2.utils.events]:  eta: 0:00:55  iter: 739  total_loss: 0.04515  loss_rpn_cls: 0.003868  loss_rpn_loc: 0.03857    time: 0.2154  last_time: 0.2080  data_time: 0.0365  last_data_time: 0.0265   lr: 0.0073926  max_mem: 1489M
# Logged iteration 740
# [06/08 04:46:33 d2.utils.events]:  eta: 0:00:51  iter: 759  total_loss: 0.0342  loss_rpn_cls: 0.004426  loss_rpn_loc: 0.02944    time: 0.2153  last_time: 0.2259  data_time: 0.0392  last_data_time: 0.0616   lr: 0.0075924  max_mem: 1489M
# Logged iteration 760
# [06/08 04:46:37 d2.utils.events]:  eta: 0:00:46  iter: 779  total_loss: 0.0449  loss_rpn_cls: 0.005631  loss_rpn_loc: 0.04058    time: 0.2151  last_time: 0.1842  data_time: 0.0298  last_data_time: 0.0053   lr: 0.0077922  max_mem: 1489M
# Logged iteration 780
# [06/08 04:46:41 d2.utils.events]:  eta: 0:00:42  iter: 799  total_loss: 0.03543  loss_rpn_cls: 0.002618  loss_rpn_loc: 0.03202    time: 0.2150  last_time: 0.2326  data_time: 0.0373  last_data_time: 0.0487   lr: 0.007992  max_mem: 1489M
# Logged iteration 800
# [06/08 04:46:45 d2.utils.events]:  eta: 0:00:38  iter: 819  total_loss: 0.03972  loss_rpn_cls: 0.003559  loss_rpn_loc: 0.03452    time: 0.2153  last_time: 0.1793  data_time: 0.0479  last_data_time: 0.0051   lr: 0.0081918  max_mem: 1489M
# Logged iteration 820
# [06/08 04:46:50 d2.utils.events]:  eta: 0:00:34  iter: 839  total_loss: 0.04758  loss_rpn_cls: 0.005552  loss_rpn_loc: 0.03949    time: 0.2151  last_time: 0.2225  data_time: 0.0277  last_data_time: 0.0448   lr: 0.0083916  max_mem: 1489M
# Logged iteration 840
# [06/08 04:46:54 d2.utils.events]:  eta: 0:00:29  iter: 859  total_loss: 0.03433  loss_rpn_cls: 0.00413  loss_rpn_loc: 0.02898    time: 0.2149  last_time: 0.1939  data_time: 0.0261  last_data_time: 0.0146   lr: 0.0085914  max_mem: 1489M
# Logged iteration 860
# [06/08 04:46:58 d2.utils.events]:  eta: 0:00:25  iter: 879  total_loss: 0.04359  loss_rpn_cls: 0.004181  loss_rpn_loc: 0.03662    time: 0.2148  last_time: 0.2145  data_time: 0.0363  last_data_time: 0.0391   lr: 0.0087912  max_mem: 1489M
# Logged iteration 880
# [06/08 04:47:02 d2.utils.events]:  eta: 0:00:21  iter: 899  total_loss: 0.03876  loss_rpn_cls: 0.004625  loss_rpn_loc: 0.03451    time: 0.2146  last_time: 0.2293  data_time: 0.0218  last_data_time: 0.0397   lr: 0.008991  max_mem: 1489M
# Logged iteration 900
# [06/08 04:47:06 d2.utils.events]:  eta: 0:00:17  iter: 919  total_loss: 0.04032  loss_rpn_cls: 0.003189  loss_rpn_loc: 0.03473    time: 0.2145  last_time: 0.1931  data_time: 0.0311  last_data_time: 0.0054   lr: 0.0091908  max_mem: 1489M
# Logged iteration 920
# [06/08 04:47:11 d2.utils.events]:  eta: 0:00:12  iter: 939  total_loss: 0.03865  loss_rpn_cls: 0.003504  loss_rpn_loc: 0.03648    time: 0.2146  last_time: 0.2002  data_time: 0.0355  last_data_time: 0.0199   lr: 0.0093906  max_mem: 1489M
# Logged iteration 940
# [06/08 04:47:15 d2.utils.events]:  eta: 0:00:08  iter: 959  total_loss: 0.03951  loss_rpn_cls: 0.005252  loss_rpn_loc: 0.03205    time: 0.2146  last_time: 0.1882  data_time: 0.0333  last_data_time: 0.0111   lr: 0.0095904  max_mem: 1489M
# Logged iteration 960
# [06/08 04:47:20 d2.utils.events]:  eta: 0:00:04  iter: 979  total_loss: 0.03343  loss_rpn_cls: 0.002882  loss_rpn_loc: 0.03053    time: 0.2149  last_time: 0.2019  data_time: 0.0417  last_data_time: 0.0249   lr: 0.0097902  max_mem: 1489M
# Logged iteration 980
# [06/08 04:47:24 d2.utils.events]:  eta: 0:00:00  iter: 999  total_loss: 0.04066  loss_rpn_cls: 0.003608  loss_rpn_loc: 0.03607    time: 0.2150  last_time: 0.1753  data_time: 0.0382  last_data_time: 0.0188   lr: 0.00999  max_mem: 1489M
# [06/08 04:47:25 d2.engine.hooks]: Overall training speed: 998 iterations in 0:03:34 (0.2150 s / it)
# [06/08 04:47:25 d2.engine.hooks]: Total training time: 0:03:36 (0:00:01 on hooks)
#   Learning Rate    Run  Minimum Loss                    Duration (s)
# ---------------  -----  ----------------------------  --------------
#        0.001000      1  (0.01084545929916203, 747)        227.022427
#        0.001000      2  (0.006948004709556699, 490)       216.224183
#        0.001000      3  (0.008940237195929512, 898)       219.066601
#        0.001000      4  (0.010407880181446671, 672)       218.003585
#        0.001000      5  (0.00620594690553844, 682)        216.038960
#        0.001000      6  (0.010334725258871913, 430)       217.874270
#        0.001000      7  (0.007477052044123411, 515)       197.600187
#        0.001000      8  (0.010741519392468035, 837)       198.874560
#        0.001000      9  (0.009575950680300593, 624)       198.592422
#        0.001000     10  (0.007964276243001223, 635)       218.928694
#        0.005000      1  (0.00832350883865729, 699)        219.787079
#        0.005000      2  (0.007737825071671978, 811)       218.290926
#        0.005000      3  (0.008697042503627017, 924)       217.507261
#        0.005000      4  (0.009215361846145242, 899)       219.460562
#        0.005000      5  (0.005483937566168606, 902)       219.232171
#        0.005000      6  (0.00538096489617601, 834)        216.775276
#        0.005000      7  (0.008273668703623116, 747)       217.526277
#        0.005000      8  (0.009619370335713029, 815)       215.335797
#        0.005000      9  (0.007658454356715083, 987)       216.583789
#        0.005000     10  (0.006842229893663898, 567)       216.754969
#        0.010000      1  (0.0037379100103862584, 800)      217.405735
#        0.010000      2  (0.007940129202324897, 215)       216.667203
#        0.010000      3  (0.0077154290629550815, 965)      216.616821
#        0.010000      4  (0.006855785613879561, 907)       197.784637
#        0.010000      5  (0.00626499013742432, 562)        217.106499
#        0.010000      6  (0.0107065633055754, 734)         215.199855
#        0.010000      7  (0.010615603532642126, 727)       216.009658
#        0.010000      8  (0.008590891462517902, 628)       217.697499
#        0.010000      9  (0.006480297015514225, 804)       216.944515
#        0.010000     10  (0.011078116716817021, 644)       217.219002
#   Learning Rate  Minimum Loss                    Total Time (s)
# ---------------  ----------------------------  ----------------
#        0.001000  (0.00620594690553844, 682)         2128.225889
#        0.005000  (0.00538096489617601, 834)         2177.254107
#        0.010000  (0.0037379100103862584, 800)       2148.651424
#
# Detailed results for learning rate: 0.001
#   Learning Rate    Run  Minimum Loss                   Duration (s)
# ---------------  -----  ---------------------------  --------------
#        0.001000      1  (0.01084545929916203, 747)       227.022427
#        0.001000      2  (0.006948004709556699, 490)      216.224183
#        0.001000      3  (0.008940237195929512, 898)      219.066601
#        0.001000      4  (0.010407880181446671, 672)      218.003585
#        0.001000      5  (0.00620594690553844, 682)       216.038960
#        0.001000      6  (0.010334725258871913, 430)      217.874270
#        0.001000      7  (0.007477052044123411, 515)      197.600187
#        0.001000      8  (0.010741519392468035, 837)      198.874560
#        0.001000      9  (0.009575950680300593, 624)      198.592422
#        0.001000     10  (0.007964276243001223, 635)      218.928694
#
# Detailed results for learning rate: 0.005
#   Learning Rate    Run  Minimum Loss                   Duration (s)
# ---------------  -----  ---------------------------  --------------
#        0.005000      1  (0.00832350883865729, 699)       219.787079
#        0.005000      2  (0.007737825071671978, 811)      218.290926
#        0.005000      3  (0.008697042503627017, 924)      217.507261
#        0.005000      4  (0.009215361846145242, 899)      219.460562
#        0.005000      5  (0.005483937566168606, 902)      219.232171
#        0.005000      6  (0.00538096489617601, 834)       216.775276
#        0.005000      7  (0.008273668703623116, 747)      217.526277
#        0.005000      8  (0.009619370335713029, 815)      215.335797
#        0.005000      9  (0.007658454356715083, 987)      216.583789
#        0.005000     10  (0.006842229893663898, 567)      216.754969
#
# Detailed results for learning rate: 0.01
#   Learning Rate    Run  Minimum Loss                    Duration (s)
# ---------------  -----  ----------------------------  --------------
#        0.010000      1  (0.0037379100103862584, 800)      217.405735
#        0.010000      2  (0.007940129202324897, 215)       216.667203
#        0.010000      3  (0.0077154290629550815, 965)      216.616821
#        0.010000      4  (0.006855785613879561, 907)       197.784637
#        0.010000      5  (0.00626499013742432, 562)        217.106499
#        0.010000      6  (0.0107065633055754, 734)         215.199855
#        0.010000      7  (0.010615603532642126, 727)       216.009658
#        0.010000      8  (0.008590891462517902, 628)       217.697499
#        0.010000      9  (0.006480297015514225, 804)       216.944515
#        0.010000     10  (0.011078116716817021, 644)       217.219002

# %%
import matplotlib.pyplot as plt

# Assuming `results` is a list of lists with the structure [learning_rate, run, (min_loss, iteration), duration]

# Extract data for plotting
learning_rates = sorted(set(result[0] for result in results))
num_runs = len([result for result in results if result[0] == learning_rates[0]])

# Prepare data for plotting
loss_data = {lr: [] for lr in learning_rates}
time_data = {lr: [] for lr in learning_rates}

for result in results:
    lr, run, (min_loss, _), duration = result
    loss_data[lr].append(min_loss)
    time_data[lr].append(duration)

# Plot minimum loss for each run
plt.figure(figsize=(10, 6))
for lr in learning_rates:
    plt.plot(range(1, num_runs + 1), loss_data[lr], marker='o', label=f'LR={lr}')
plt.xlabel('Run')
plt.ylabel('Minimum Loss')
plt.title('Minimum Loss for Each Run Across Different Learning Rates')
plt.legend()
plt.grid(True)
plt.show()

# Plot total time for each run
plt.figure(figsize=(10, 6))
for lr in learning_rates:
    plt.plot(range(1, num_runs + 1), time_data[lr], marker='o', label=f'LR={lr}')
plt.xlabel('Run')
plt.ylabel('Duration (s)')
plt.title('Total Time for Each Run Across Different Learning Rates')
plt.legend()
plt.grid(True)
plt.show()

# Box plot of minimum losses
plt.figure(figsize=(10, 6))
plt.boxplot([loss_data[lr] for lr in learning_rates], labels=[f'LR={lr}' for lr in learning_rates])
plt.xlabel('Learning Rate')
plt.ylabel('Minimum Loss')
plt.title('Box Plot of Minimum Losses for Each Learning Rate')
plt.grid(True)
plt.show()

# Box plot of total durations
plt.figure(figsize=(10, 6))
plt.boxplot([time_data[lr] for lr in learning_rates], labels=[f'LR={lr}' for lr in learning_rates])
plt.xlabel('Learning Rate')
plt.ylabel('Duration (s)')
plt.title('Box Plot of Total Durations for Each Learning Rate')
plt.grid(True)
plt.show()

# Scatter plot of minimum loss vs. duration
plt.figure(figsize=(10, 6))
for lr in learning_rates:
    plt.scatter(time_data[lr], loss_data[lr], label=f'LR={lr}')
plt.xlabel('Duration (s)')
plt.ylabel('Minimum Loss')
plt.title('Scatter Plot of Minimum Loss vs. Duration')
plt.legend()
plt.grid(True)
plt.show()
