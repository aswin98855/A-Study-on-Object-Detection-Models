# %%
import sys, os, distutils.core
from IPython.display import clear_output

# !python -m pip install pyyaml==5.1
# !git clone 'https://github.com/facebookresearch/detectron2'
dist = distutils.core.run_setup("./detectron2/setup.py")
# !python -m pip install {' '.join([f"'{x}'" for x in dist.install_requires])}
sys.path.insert(0, os.path.abspath('./detectron2'))
# Out:
# Collecting pyyaml==5.1
#   Downloading PyYAML-5.1.tar.gz (274 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.2/274.2 kB 8.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: pyyaml
#   Building wheel for pyyaml (setup.py) ... done
#   Created wheel for pyyaml: filename=PyYAML-5.1-cp310-cp310-linux_x86_64.whl size=44090 sha256=8579dc8e15a83d14098082b26d7caf0921c58baaa7810cc4217fffbd0d12f6ca
#   Stored in directory: /root/.cache/pip/wheels/70/83/31/975b737609aba39a4099d471d5684141c1fdc3404f97e7f68a
# Successfully built pyyaml
# Installing collected packages: pyyaml
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0
#     Uninstalling PyYAML-6.0:
#       Successfully uninstalled PyYAML-6.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dask-cudf 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# dask 2023.9.0 requires pyyaml>=5.3.1, but you have pyyaml 5.1 which is incompatible.
# dask-cuda 23.8.0 requires dask==2023.7.1, but you have dask 2023.9.0 which is incompatible.
# dask-cuda 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.0.2 which is incompatible.
# dask-cudf 23.8.0 requires dask==2023.7.1, but you have dask 2023.9.0 which is incompatible.
# dask-cudf 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.0.2 which is incompatible.
# distributed 2023.7.1 requires dask==2023.7.1, but you have dask 2023.9.0 which is incompatible.
# distributed 2023.7.1 requires pyyaml>=5.3.1, but you have pyyaml 5.1 which is incompatible.
# flax 0.7.2 requires PyYAML>=5.4.1, but you have pyyaml 5.1 which is incompatible.
# jupyter-events 0.6.3 requires pyyaml>=5.3, but you have pyyaml 5.1 which is incompatible.
# jupyterlab-lsp 4.2.0 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# kfp 2.0.1 requires google-cloud-storage<3,>=2.2.1, but you have google-cloud-storage 1.44.0 which is incompatible.
# kfp 2.0.1 requires PyYAML<7,>=5.3, but you have pyyaml 5.1 which is incompatible.
# kubernetes 26.1.0 requires pyyaml>=5.4.1, but you have pyyaml 5.1 which is incompatible.
# pytorch-lightning 2.0.8 requires PyYAML>=5.4, but you have pyyaml 5.1 which is incompatible.
# raft-dask 23.8.0 requires dask==2023.7.1, but you have dask 2023.9.0 which is incompatible.
# ydata-profiling 4.3.1 requires scipy<1.11,>=1.4.1, but you have scipy 1.11.2 which is incompatible.
# Successfully installed pyyaml-5.1
# Cloning into 'detectron2'...
# remote: Enumerating objects: 15725, done.
# remote: Counting objects: 100% (448/448), done.
# remote: Compressing objects: 100% (337/337), done.
# remote: Total 15725 (delta 201), reused 301 (delta 102), pack-reused 15277
# Receiving objects: 100% (15725/15725), 6.51 MiB | 23.32 MiB/s, done.
# Resolving deltas: 100% (11317/11317), done.
# Requirement already satisfied: Pillow>=7.1 in /opt/conda/lib/python3.10/site-packages (9.5.0)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (3.7.2)
# Collecting pycocotools>=2.0.2
#   Downloading pycocotools-2.0.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (426 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 426.2/426.2 kB 11.5 MB/s eta 0:00:0000:01
# Requirement already satisfied: termcolor>=1.1 in /opt/conda/lib/python3.10/site-packages (2.3.0)
# Collecting yacs>=0.1.8
#   Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Requirement already satisfied: tabulate in /opt/conda/lib/python3.10/site-packages (0.9.0)
# Requirement already satisfied: cloudpickle in /opt/conda/lib/python3.10/site-packages (2.2.1)
# Requirement already satisfied: tqdm>4.29.0 in /opt/conda/lib/python3.10/site-packages (4.66.1)
# Requirement already satisfied: tensorboard in /opt/conda/lib/python3.10/site-packages (2.12.3)
# Collecting fvcore<0.1.6,>=0.1.5
#   Downloading fvcore-0.1.5.post20221221.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 4.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting iopath<0.1.10,>=0.1.7
#   Downloading iopath-0.1.9-py3-none-any.whl (27 kB)
# Collecting omegaconf<2.4,>=2.1
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 8.4 MB/s eta 0:00:00
# Collecting hydra-core>=1.1
#   Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 14.7 MB/s eta 0:00:00
# Collecting black
#   Downloading black-24.4.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 60.4 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (21.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: PyYAML in /opt/conda/lib/python3.10/site-packages (from yacs>=0.1.8) (5.1)
# Requirement already satisfied: absl-py>=0.4 in /opt/conda/lib/python3.10/site-packages (from tensorboard) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /opt/conda/lib/python3.10/site-packages (from tensorboard) (1.51.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /opt/conda/lib/python3.10/site-packages (from tensorboard) (2.20.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /opt/conda/lib/python3.10/site-packages (from tensorboard) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.10/site-packages (from tensorboard) (3.4.3)
# Requirement already satisfied: protobuf>=3.19.6 in /opt/conda/lib/python3.10/site-packages (from tensorboard) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard) (2.31.0)
# Requirement already satisfied: setuptools>=41.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard) (68.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from tensorboard) (2.3.7)
# Requirement already satisfied: wheel>=0.26 in /opt/conda/lib/python3.10/site-packages (from tensorboard) (0.40.0)
# Collecting portalocker (from iopath<0.1.10,>=0.1.7)
#   Downloading portalocker-2.8.2-py3-none-any.whl (17 kB)
# Collecting antlr4-python3-runtime==4.9.* (from omegaconf<2.4,>=2.1)
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 10.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: click>=8.0.0 in /opt/conda/lib/python3.10/site-packages (from black) (8.1.7)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /opt/conda/lib/python3.10/site-packages (from black) (1.0.0)
# Collecting packaging
#   Downloading packaging-24.0-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.5/53.5 kB 5.1 MB/s eta 0:00:00
# Collecting pathspec>=0.9.0 (from black)
#   Downloading pathspec-0.12.1-py3-none-any.whl (31 kB)
# Requirement already satisfied: platformdirs>=2 in /opt/conda/lib/python3.10/site-packages (from black) (3.10.0)
# Requirement already satisfied: tomli>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from black) (2.0.1)
# Requirement already satisfied: typing-extensions>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from black) (4.6.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard) (0.2.7)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard) (4.9)
# Requirement already satisfied: six>=1.9.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard) (1.16.0)
# Requirement already satisfied: urllib3<2.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard) (1.26.15)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard) (2.1.3)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/conda/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard) (3.2.2)
# Building wheels for collected packages: fvcore, antlr4-python3-runtime
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61405 sha256=7b16036a02a4c1b741208e9a5045b5896769d008f5ef52b7079ef66289535e01
#   Stored in directory: /root/.cache/pip/wheels/01/c0/af/77c1cf53a1be9e42a52b48e5af2169d40ec2e89f7362489dd0
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=755a69c0392a282f9e86e2e11f7895941f55d81fc86d30717d0980821f3e5bc1
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
# Successfully built fvcore antlr4-python3-runtime
# Installing collected packages: antlr4-python3-runtime, yacs, portalocker, pathspec, packaging, omegaconf, iopath, hydra-core, black, pycocotools, fvcore
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.3
#     Uninstalling packaging-21.3:
#       Successfully uninstalled packaging-21.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# cuml 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# dask-cudf 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# cudf 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.0.2 which is incompatible.
# cudf 23.8.0 requires protobuf<5,>=4.21, but you have protobuf 3.20.3 which is incompatible.
# cuml 23.8.0 requires dask==2023.7.1, but you have dask 2023.9.0 which is incompatible.
# dask 2023.9.0 requires pyyaml>=5.3.1, but you have pyyaml 5.1 which is incompatible.
# dask-cuda 23.8.0 requires dask==2023.7.1, but you have dask 2023.9.0 which is incompatible.
# dask-cuda 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.0.2 which is incompatible.
# dask-cudf 23.8.0 requires dask==2023.7.1, but you have dask 2023.9.0 which is incompatible.
# dask-cudf 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.0.2 which is incompatible.
# distributed 2023.7.1 requires dask==2023.7.1, but you have dask 2023.9.0 which is incompatible.
# distributed 2023.7.1 requires pyyaml>=5.3.1, but you have pyyaml 5.1 which is incompatible.
# google-cloud-bigquery 2.34.4 requires packaging<22.0dev,>=14.3, but you have packaging 24.0 which is incompatible.
# jupyterlab-lsp 4.2.0 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# momepy 0.6.0 requires shapely>=2, but you have shapely 1.8.5.post1 which is incompatible.
# pymc3 3.11.5 requires numpy<1.22.2,>=1.15.0, but you have numpy 1.23.5 which is incompatible.
# pymc3 3.11.5 requires scipy<1.8.0,>=1.7.3, but you have scipy 1.11.2 which is incompatible.
# pytorch-lightning 2.0.8 requires PyYAML>=5.4, but you have pyyaml 5.1 which is incompatible.
# raft-dask 23.8.0 requires dask==2023.7.1, but you have dask 2023.9.0 which is incompatible.
# ydata-profiling 4.3.1 requires scipy<1.11,>=1.4.1, but you have scipy 1.11.2 which is incompatible.
# Successfully installed antlr4-python3-runtime-4.9.3 black-24.4.2 fvcore-0.1.5.post20221221 hydra-core-1.3.2 iopath-0.1.9 omegaconf-2.3.0 packaging-24.0 pathspec-0.12.1 portalocker-2.8.2 pycocotools-2.0.7 yacs-0.1.8

# %%
# Importing dependencies

import torch, detectron2
from detectron2.utils.logger import setup_logger
setup_logger()
print("detectron2 version:", detectron2.__version__)

import numpy as np
import os, json, cv2, random
from IPython import display
import PIL
import matplotlib.pyplot as plt

# importing detectron2 utilities
from detectron2 import model_zoo
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog, DatasetCatalog


SEED = 10
THRESHOLD = 0.8
# Out:
# detectron2 version: 0.6

# %%
# Creating coco instances

from detectron2.data.datasets import register_coco_instances
from detectron2.structures import BoxMode

    
register_coco_instances(f"tomato_dataset_train", {},
                        f"/kaggle/input/tomatod/annotations/tomatOD_train.json",
                        f"/kaggle/input/tomatod/images/train")

register_coco_instances(f"tomato_dataset_test", {},
                        f"/kaggle/input/tomatod/annotations/tomatOD_test.json",
                        f"/kaggle/input/tomatod/images/val")

# %%
# Examples from the training dataset

import random
from detectron2.utils.visualizer import Visualizer

my_dataset_train_metadata = MetadataCatalog.get("tomato_dataset_train")
train_dataset_dicts = DatasetCatalog.get("tomato_dataset_train")

# A function that creates examples from the dataset
def create_random_images(dataset_dict,dataset_metadata, seed, image_scale = 0.7):
    np.random.seed(seed)
    images = np.random.permutation(dataset_dict)[:2]
    
    fig, axs = plt.subplots(1,2, figsize = (12,6), dpi = 100)
    for i in range(2):
        im = images[i]
        img_link = im['file_name']
        img_id = im['image_id']
        img = cv2.imread(img_link)
        img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
        visualizer = Visualizer(img, metadata= dataset_metadata, scale=image_scale)
        vis = visualizer.draw_dataset_dict(im)
        final_img = vis.get_image()
        
        axs[i].set_title('image id: ' + str(img_id), fontsize = 10)
        axs[i].axis('off')
        axs[i].imshow(final_img)
# Out:
# [06/08 05:11:19 d2.data.datasets.coco]: Loaded 222 images in COCO format from /kaggle/input/tomatod/annotations/tomatOD_train.json

# %%
create_random_images(train_dataset_dicts, my_dataset_train_metadata, seed = 5, image_scale = 1)

# %%
import os
import logging
import time
from detectron2.engine import DefaultTrainer, HookBase
from detectron2.config import get_cfg
from detectron2 import model_zoo
from tabulate import tabulate

# Configure logging
log_file = 'training_log.txt'
logging.basicConfig(filename=log_file, level=logging.INFO)

# Print message to console to confirm logging setup
print(f"Logging to {log_file}")

# List of learning rates to experiment with
learning_rates = [0.001, 0.005, 0.01]

# Number of iterations and runs
num_iterations = 1000
num_runs = 10

# Data structure to store results
results = []

# Custom hook to log the training progress
class LossLoggerHook(HookBase):
    def __init__(self):
        super().__init__()

    def after_step(self):
        if self.trainer.storage.iter % 20 == 0:  # Log every 20 iterations
            total_loss = self.trainer.storage.history("total_loss").latest()
            logging.info(f"iter: {self.trainer.storage.iter} total_loss: {total_loss}")
            print(f"Logged iteration {self.trainer.storage.iter}")

# Function to train with a specific learning rate
def train_with_learning_rate(lr):
    cfg = get_cfg()
    cfg.merge_from_file(model_zoo.get_config_file("COCO-Detection/rpn_R_50_C4_1x.yaml"))
    cfg.DATASETS.TRAIN = ('tomato_dataset_train',)
    cfg.DATASETS.TEST = ()  # no metrics implemented for this dataset
    cfg.DATALOADER.NUM_WORKERS = 2
    cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-Detection/rpn_R_50_C4_1x.yaml")
    cfg.SOLVER.IMS_PER_BATCH = 2
    cfg.SOLVER.MAX_ITER = num_iterations
    cfg.SOLVER.STEPS = []  # do not decay learning rate
    cfg.MODEL.ROI_HEADS.NUM_CLASSES = 3
    cfg.SOLVER.BASE_LR = lr  # Set learning rate

    # Implement gradient clipping correctly
    cfg.SOLVER.CLIP_GRADIENTS.ENABLED = True
    cfg.SOLVER.CLIP_GRADIENTS.CLIP_TYPE = "norm"
    cfg.SOLVER.CLIP_GRADIENTS.CLIP_VALUE = 1.0

    os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)
    trainer = DefaultTrainer(cfg)
    trainer.register_hooks([LossLoggerHook()])

    start_time = time.time()
    trainer.resume_or_load(resume=False)
    trainer.train()
    end_time = time.time()

    # Get the minimum loss over all iterations
    min_loss = min(trainer.storage.history("total_loss").values())

    return min_loss, end_time - start_time

# Run training for each learning rate
for lr in learning_rates:
    lr_results = []
    for run in range(num_runs):
        logging.info(f"Starting training with learning rate: {lr}, run: {run + 1}")
        print(f"Starting training with learning rate: {lr}, run: {run + 1}")
        min_loss, duration = train_with_learning_rate(lr)
        lr_results.append([lr, run + 1, min_loss, duration])
    results.extend(lr_results)

# Aggregate results for each learning rate
summary_results = []
for lr in learning_rates:
    lr_runs = [result for result in results if result[0] == lr]
    min_loss = min(lr_runs, key=lambda x: x[2])[2]
    total_time = sum(run[3] for run in lr_runs)
    summary_results.append([lr, min_loss, total_time])

# Tabulate the detailed results for each run
headers = ["Learning Rate", "Run", "Minimum Loss", "Duration (s)"]
print(tabulate(results, headers, floatfmt=".6f"))

# Log the detailed results to the file
logging.info(tabulate(results, headers, floatfmt=".6f"))

# Tabulate and print the summary results
summary_headers = ["Learning Rate", "Minimum Loss", "Total Time (s)"]
print(tabulate(summary_results, summary_headers, floatfmt=".6f"))

# Log the summary results to the file
logging.info(tabulate(summary_results, summary_headers, floatfmt=".6f"))

# Tabulate the detailed results for each learning rate
for lr in learning_rates:
    lr_runs = [result for result in results if result[0] == lr]
    print(f"\nDetailed results for learning rate: {lr}")
    print(tabulate(lr_runs, headers, floatfmt=".6f"))
    logging.info(f"\nDetailed results for learning rate: {lr}")
    logging.info(tabulate(lr_runs, headers, floatfmt=".6f"))
# Out:
# Logging to training_log.txt
# Starting training with learning rate: 0.001, run: 1
# [06/08 05:11:23 d2.engine.defaults]: Model:
# ProposalNetwork(
#   (backbone): ResNet(
#     (stem): BasicStem(
#       (conv1): Conv2d(
#         3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#         (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#       )
#     )
#     (res2): Sequential(
#       (0): BottleneckBlock(
#         (shortcut): Conv2d(
#           64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv1): Conv2d(
#           64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#       )
#       (1): BottleneckBlock(
#         (conv1): Conv2d(
#           256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#       )
#       (2): BottleneckBlock(
#         (conv1): Conv2d(
#           256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#       )
#     )
#     (res3): Sequential(
#       (0): BottleneckBlock(
#         (shortcut): Conv2d(
#           256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#         (conv1): Conv2d(
#           256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#       )
#       (1): BottleneckBlock(
#         (conv1): Conv2d(
#           512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#       )
#       (2): BottleneckBlock(
#         (conv1): Conv2d(
#           512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#       )
#       (3): BottleneckBlock(
#         (conv1): Conv2d(
#           512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#       )
#     )
#     (res4): Sequential(
#       (0): BottleneckBlock(
#         (shortcut): Conv2d(
#           512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#         (conv1): Conv2d(
#           512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#       )
#       (1): BottleneckBlock(
#         (conv1): Conv2d(
#           1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#       )
#       (2): BottleneckBlock(
#         (conv1): Conv2d(
#           1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#       )
#       (3): BottleneckBlock(
#         (conv1): Conv2d(
#           1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#       )
#       (4): BottleneckBlock(
#         (conv1): Conv2d(
#           1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#       )
#       (5): BottleneckBlock(
#         (conv1): Conv2d(
#           1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(
#         1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (objectness_logits): Conv2d(1024, 15, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(1024, 60, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
# )
# [06/08 05:11:23 d2.data.datasets.coco]: Loaded 222 images in COCO format from /kaggle/input/tomatod/annotations/tomatOD_train.json
# [06/08 05:11:23 d2.data.build]: Removed 0 images with no usable annotations. 222 images left.
# [06/08 05:11:23 d2.data.build]: Distribution of instances among all 3 categories:
# |  category  | #instances   |  category  | #instances   |  category  | #instances   |
# |:----------:|:-------------|:----------:|:-------------|:----------:|:-------------|
# |   unripe   | 1301         | semi-ripe  | 320          | fully-ripe | 332          |
# |            |              |            |              |            |              |
# |   total    | 1953         |            |              |            |              |
# [06/08 05:11:23 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), RandomFlip()]
# [06/08 05:11:23 d2.data.build]: Using training sampler TrainingSampler
# [06/08 05:11:23 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [06/08 05:11:23 d2.data.common]: Serializing 222 elements to byte tensors and concatenating them all ...
# [06/08 05:11:23 d2.data.common]: Serialized dataset takes 0.10 MiB
# [06/08 05:11:23 d2.data.build]: Making batched data loader with batch_size=2
# [06/08 05:11:23 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from https://dl.fbaipublicfiles.com/detectron2/COCO-Detection/rpn_R_50_C4_1x/137258005/model_final_450694.pkl ...
# model_final_450694.pkl: 72.4MB [00:00, 144MB/s]
# [06/08 05:11:23 d2.engine.train_loop]: Starting training from iteration 0
# /opt/conda/lib/python3.10/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /usr/local/src/pytorch/aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Logged iteration 0
# [06/08 05:11:30 d2.utils.events]:  eta: 0:03:05  iter: 19  total_loss: 0.1457  loss_rpn_cls: 0.1273  loss_rpn_loc: 0.01613    time: 0.1862  last_time: 0.1574  data_time: 0.0666  last_data_time: 0.0492   lr: 1.9981e-05  max_mem: 942M
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Logged iteration 20
# [06/08 05:11:43 d2.utils.events]:  eta: 0:02:59  iter: 39  total_loss: 0.1238  loss_rpn_cls: 0.1069  loss_rpn_loc: 0.01348    time: 0.1854  last_time: 0.1966  data_time: 0.0523  last_data_time: 0.0697   lr: 3.9961e-05  max_mem: 943M
# Logged iteration 40
# [06/08 05:11:47 d2.utils.events]:  eta: 0:03:00  iter: 59  total_loss: 0.0981  loss_rpn_cls: 0.08267  loss_rpn_loc: 0.01532    time: 0.1888  last_time: 0.1586  data_time: 0.0628  last_data_time: 0.0359   lr: 5.9941e-05  max_mem: 943M
# Logged iteration 60
# [06/08 05:11:50 d2.utils.events]:  eta: 0:02:57  iter: 79  total_loss: 0.06787  loss_rpn_cls: 0.05087  loss_rpn_loc: 0.01255    time: 0.1890  last_time: 0.1567  data_time: 0.0652  last_data_time: 0.0372   lr: 7.9921e-05  max_mem: 943M
# Logged iteration 80
# [06/08 05:11:54 d2.utils.events]:  eta: 0:02:53  iter: 99  total_loss: 0.05139  loss_rpn_cls: 0.04009  loss_rpn_loc: 0.01184    time: 0.1890  last_time: 0.2181  data_time: 0.0646  last_data_time: 0.0815   lr: 9.9901e-05  max_mem: 943M
# Logged iteration 100
# [06/08 05:11:58 d2.utils.events]:  eta: 0:02:46  iter: 119  total_loss: 0.05342  loss_rpn_cls: 0.04115  loss_rpn_loc: 0.01264    time: 0.1881  last_time: 0.1759  data_time: 0.0542  last_data_time: 0.0541   lr: 0.00011988  max_mem: 943M
# Logged iteration 120
# [06/08 05:12:02 d2.utils.events]:  eta: 0:02:42  iter: 139  total_loss: 0.04132  loss_rpn_cls: 0.02664  loss_rpn_loc: 0.01347    time: 0.1869  last_time: 0.1999  data_time: 0.0512  last_data_time: 0.0605   lr: 0.00013986  max_mem: 943M
# Logged iteration 140
# [06/08 05:12:05 d2.utils.events]:  eta: 0:02:38  iter: 159  total_loss: 0.04325  loss_rpn_cls: 0.02649  loss_rpn_loc: 0.01653    time: 0.1863  last_time: 0.1882  data_time: 0.0534  last_data_time: 0.0587   lr: 0.00015984  max_mem: 943M
# Logged iteration 160
# [06/08 05:12:09 d2.utils.events]:  eta: 0:02:34  iter: 179  total_loss: 0.04003  loss_rpn_cls: 0.02589  loss_rpn_loc: 0.01486    time: 0.1880  last_time: 0.1821  data_time: 0.0695  last_data_time: 0.0636   lr: 0.00017982  max_mem: 943M
# Logged iteration 180
# [06/08 05:12:13 d2.utils.events]:  eta: 0:02:30  iter: 199  total_loss: 0.03617  loss_rpn_cls: 0.02285  loss_rpn_loc: 0.013    time: 0.1879  last_time: 0.1941  data_time: 0.0587  last_data_time: 0.0692   lr: 0.0001998  max_mem: 943M
# Logged iteration 200
# [06/08 05:12:17 d2.utils.events]:  eta: 0:02:27  iter: 219  total_loss: 0.02964  loss_rpn_cls: 0.01847  loss_rpn_loc: 0.01058    time: 0.1880  last_time: 0.1984  data_time: 0.0617  last_data_time: 0.0705   lr: 0.00021978  max_mem: 943M
# Logged iteration 220
# [06/08 05:12:20 d2.utils.events]:  eta: 0:02:23  iter: 239  total_loss: 0.02381  loss_rpn_cls: 0.01147  loss_rpn_loc: 0.01288    time: 0.1872  last_time: 0.2002  data_time: 0.0498  last_data_time: 0.0628   lr: 0.00023976  max_mem: 943M
# Logged iteration 240
# [06/08 05:12:24 d2.utils.events]:  eta: 0:02:19  iter: 259  total_loss: 0.02757  loss_rpn_cls: 0.0143  loss_rpn_loc: 0.01206    time: 0.1871  last_time: 0.2608  data_time: 0.0481  last_data_time: 0.1037   lr: 0.00025974  max_mem: 943M
# Logged iteration 260
# [06/08 05:12:28 d2.utils.events]:  eta: 0:02:15  iter: 279  total_loss: 0.02402  loss_rpn_cls: 0.01268  loss_rpn_loc: 0.01096    time: 0.1870  last_time: 0.2180  data_time: 0.0528  last_data_time: 0.0752   lr: 0.00027972  max_mem: 943M
# Logged iteration 280
# [06/08 05:12:32 d2.utils.events]:  eta: 0:02:11  iter: 299  total_loss: 0.02303  loss_rpn_cls: 0.01112  loss_rpn_loc: 0.01267    time: 0.1867  last_time: 0.1833  data_time: 0.0499  last_data_time: 0.0562   lr: 0.0002997  max_mem: 943M
# Logged iteration 300
# [06/08 05:12:35 d2.utils.events]:  eta: 0:02:08  iter: 319  total_loss: 0.03402  loss_rpn_cls: 0.0189  loss_rpn_loc: 0.01427    time: 0.1870  last_time: 0.1989  data_time: 0.0610  last_data_time: 0.0735   lr: 0.00031968  max_mem: 943M
# Logged iteration 320
# [06/08 05:12:39 d2.utils.events]:  eta: 0:02:04  iter: 339  total_loss: 0.02792  loss_rpn_cls: 0.01415  loss_rpn_loc: 0.01178    time: 0.1875  last_time: 0.2678  data_time: 0.0617  last_data_time: 0.1257   lr: 0.00033966  max_mem: 943M
# Logged iteration 340
# [06/08 05:12:43 d2.utils.events]:  eta: 0:02:00  iter: 359  total_loss: 0.02529  loss_rpn_cls: 0.01175  loss_rpn_loc: 0.01255    time: 0.1879  last_time: 0.1797  data_time: 0.0545  last_data_time: 0.0539   lr: 0.00035964  max_mem: 943M
# Logged iteration 360
# [06/08 05:12:47 d2.utils.events]:  eta: 0:01:56  iter: 379  total_loss: 0.02639  loss_rpn_cls: 0.0142  loss_rpn_loc: 0.01272    time: 0.1876  last_time: 0.1907  data_time: 0.0470  last_data_time: 0.0712   lr: 0.00037962  max_mem: 943M
# Logged iteration 380
# [06/08 05:12:50 d2.utils.events]:  eta: 0:01:52  iter: 399  total_loss: 0.0235  loss_rpn_cls: 0.0115  loss_rpn_loc: 0.01102    time: 0.1870  last_time: 0.1268  data_time: 0.0415  last_data_time: 0.0116   lr: 0.0003996  max_mem: 943M
# Logged iteration 400
# [06/08 05:12:54 d2.utils.events]:  eta: 0:01:48  iter: 419  total_loss: 0.02289  loss_rpn_cls: 0.01066  loss_rpn_loc: 0.01221    time: 0.1867  last_time: 0.1720  data_time: 0.0468  last_data_time: 0.0380   lr: 0.00041958  max_mem: 943M
# Logged iteration 420
# [06/08 05:12:58 d2.utils.events]:  eta: 0:01:44  iter: 439  total_loss: 0.02725  loss_rpn_cls: 0.01275  loss_rpn_loc: 0.01297    time: 0.1863  last_time: 0.1804  data_time: 0.0478  last_data_time: 0.0607   lr: 0.00043956  max_mem: 943M
# Logged iteration 440
# [06/08 05:13:01 d2.utils.events]:  eta: 0:01:40  iter: 459  total_loss: 0.024  loss_rpn_cls: 0.009466  loss_rpn_loc: 0.01278    time: 0.1862  last_time: 0.1753  data_time: 0.0550  last_data_time: 0.0453   lr: 0.00045954  max_mem: 943M
# Logged iteration 460
# [06/08 05:13:05 d2.utils.events]:  eta: 0:01:36  iter: 479  total_loss: 0.01804  loss_rpn_cls: 0.007482  loss_rpn_loc: 0.01125    time: 0.1860  last_time: 0.1672  data_time: 0.0534  last_data_time: 0.0377   lr: 0.00047952  max_mem: 943M
# Logged iteration 480
# [06/08 05:13:09 d2.utils.events]:  eta: 0:01:32  iter: 499  total_loss: 0.02251  loss_rpn_cls: 0.00911  loss_rpn_loc: 0.01293    time: 0.1863  last_time: 0.1845  data_time: 0.0613  last_data_time: 0.0565   lr: 0.0004995  max_mem: 943M
# Logged iteration 500
# [06/08 05:13:13 d2.utils.events]:  eta: 0:01:29  iter: 519  total_loss: 0.02201  loss_rpn_cls: 0.009036  loss_rpn_loc: 0.01235    time: 0.1867  last_time: 0.1985  data_time: 0.0603  last_data_time: 0.0503   lr: 0.00051948  max_mem: 943M
# Logged iteration 520
# [06/08 05:13:16 d2.utils.events]:  eta: 0:01:25  iter: 539  total_loss: 0.02028  loss_rpn_cls: 0.008731  loss_rpn_loc: 0.0109    time: 0.1866  last_time: 0.2000  data_time: 0.0514  last_data_time: 0.0710   lr: 0.00053946  max_mem: 943M
# Logged iteration 540
# [06/08 05:13:20 d2.utils.events]:  eta: 0:01:22  iter: 559  total_loss: 0.02205  loss_rpn_cls: 0.008312  loss_rpn_loc: 0.01203    time: 0.1867  last_time: 0.1871  data_time: 0.0583  last_data_time: 0.0700   lr: 0.00055944  max_mem: 943M
# Logged iteration 560
# [06/08 05:13:24 d2.utils.events]:  eta: 0:01:18  iter: 579  total_loss: 0.02296  loss_rpn_cls: 0.009438  loss_rpn_loc: 0.01254    time: 0.1867  last_time: 0.1854  data_time: 0.0581  last_data_time: 0.0667   lr: 0.00057942  max_mem: 943M
# Logged iteration 580
# [06/08 05:13:28 d2.utils.events]:  eta: 0:01:14  iter: 599  total_loss: 0.01658  loss_rpn_cls: 0.005553  loss_rpn_loc: 0.0102    time: 0.1868  last_time: 0.1528  data_time: 0.0572  last_data_time: 0.0092   lr: 0.0005994  max_mem: 943M
# Logged iteration 600
# [06/08 05:13:32 d2.utils.events]:  eta: 0:01:10  iter: 619  total_loss: 0.02136  loss_rpn_cls: 0.01006  loss_rpn_loc: 0.009942    time: 0.1869  last_time: 0.1780  data_time: 0.0471  last_data_time: 0.0591   lr: 0.00061938  max_mem: 943M
# Logged iteration 620
# [06/08 05:13:35 d2.utils.events]:  eta: 0:01:07  iter: 639  total_loss: 0.02465  loss_rpn_cls: 0.01164  loss_rpn_loc: 0.01225    time: 0.1869  last_time: 0.2074  data_time: 0.0499  last_data_time: 0.0695   lr: 0.00063936  max_mem: 943M
# Logged iteration 640
# [06/08 05:13:39 d2.utils.events]:  eta: 0:01:03  iter: 659  total_loss: 0.01682  loss_rpn_cls: 0.006588  loss_rpn_loc: 0.01085    time: 0.1864  last_time: 0.1628  data_time: 0.0413  last_data_time: 0.0334   lr: 0.00065934  max_mem: 943M
# Logged iteration 660
# [06/08 05:13:42 d2.utils.events]:  eta: 0:00:59  iter: 679  total_loss: 0.01888  loss_rpn_cls: 0.006504  loss_rpn_loc: 0.01279    time: 0.1864  last_time: 0.2331  data_time: 0.0519  last_data_time: 0.0841   lr: 0.00067932  max_mem: 943M
# Logged iteration 680
# [06/08 05:13:46 d2.utils.events]:  eta: 0:00:55  iter: 699  total_loss: 0.01968  loss_rpn_cls: 0.007665  loss_rpn_loc: 0.01242    time: 0.1866  last_time: 0.1943  data_time: 0.0611  last_data_time: 0.0652   lr: 0.0006993  max_mem: 943M
# Logged iteration 700
# [06/08 05:13:50 d2.utils.events]:  eta: 0:00:52  iter: 719  total_loss: 0.01754  loss_rpn_cls: 0.005454  loss_rpn_loc: 0.009197    time: 0.1868  last_time: 0.1915  data_time: 0.0565  last_data_time: 0.0604   lr: 0.00071928  max_mem: 943M
# Logged iteration 720
# [06/08 05:13:54 d2.utils.events]:  eta: 0:00:48  iter: 739  total_loss: 0.01996  loss_rpn_cls: 0.00757  loss_rpn_loc: 0.01296    time: 0.1871  last_time: 0.2241  data_time: 0.0598  last_data_time: 0.0620   lr: 0.00073926  max_mem: 943M
# Logged iteration 740
# [06/08 05:13:58 d2.utils.events]:  eta: 0:00:44  iter: 759  total_loss: 0.02185  loss_rpn_cls: 0.007286  loss_rpn_loc: 0.0116    time: 0.1867  last_time: 0.1542  data_time: 0.0449  last_data_time: 0.0275   lr: 0.00075924  max_mem: 943M
# Logged iteration 760
# [06/08 05:14:01 d2.utils.events]:  eta: 0:00:41  iter: 779  total_loss: 0.01578  loss_rpn_cls: 0.005583  loss_rpn_loc: 0.009299    time: 0.1866  last_time: 0.1814  data_time: 0.0501  last_data_time: 0.0525   lr: 0.00077922  max_mem: 943M
# Logged iteration 780
# [06/08 05:14:05 d2.utils.events]:  eta: 0:00:37  iter: 799  total_loss: 0.01961  loss_rpn_cls: 0.008606  loss_rpn_loc: 0.01164    time: 0.1865  last_time: 0.2018  data_time: 0.0582  last_data_time: 0.0723   lr: 0.0007992  max_mem: 943M
# Logged iteration 800
# [06/08 05:14:09 d2.utils.events]:  eta: 0:00:33  iter: 819  total_loss: 0.01922  loss_rpn_cls: 0.005406  loss_rpn_loc: 0.01244    time: 0.1866  last_time: 0.1959  data_time: 0.0592  last_data_time: 0.0688   lr: 0.00081918  max_mem: 943M
# Logged iteration 820
# [06/08 05:14:12 d2.utils.events]:  eta: 0:00:29  iter: 839  total_loss: 0.01854  loss_rpn_cls: 0.005137  loss_rpn_loc: 0.01173    time: 0.1864  last_time: 0.1876  data_time: 0.0460  last_data_time: 0.0598   lr: 0.00083916  max_mem: 943M
# Logged iteration 840
# [06/08 05:14:16 d2.utils.events]:  eta: 0:00:26  iter: 859  total_loss: 0.01786  loss_rpn_cls: 0.006687  loss_rpn_loc: 0.01097    time: 0.1868  last_time: 0.1604  data_time: 0.0701  last_data_time: 0.0328   lr: 0.00085914  max_mem: 943M
# Logged iteration 860
# [06/08 05:14:20 d2.utils.events]:  eta: 0:00:22  iter: 879  total_loss: 0.01564  loss_rpn_cls: 0.004276  loss_rpn_loc: 0.01088    time: 0.1867  last_time: 0.1870  data_time: 0.0570  last_data_time: 0.0581   lr: 0.00087912  max_mem: 943M
# Logged iteration 880
# [06/08 05:14:24 d2.utils.events]:  eta: 0:00:18  iter: 899  total_loss: 0.01611  loss_rpn_cls: 0.004664  loss_rpn_loc: 0.01034    time: 0.1869  last_time: 0.2047  data_time: 0.0614  last_data_time: 0.0736   lr: 0.0008991  max_mem: 943M
# Logged iteration 900
# [06/08 05:14:28 d2.utils.events]:  eta: 0:00:14  iter: 919  total_loss: 0.01532  loss_rpn_cls: 0.006222  loss_rpn_loc: 0.009283    time: 0.1868  last_time: 0.1458  data_time: 0.0529  last_data_time: 0.0312   lr: 0.00091908  max_mem: 943M
# Logged iteration 920
# [06/08 05:14:31 d2.utils.events]:  eta: 0:00:11  iter: 939  total_loss: 0.01767  loss_rpn_cls: 0.005312  loss_rpn_loc: 0.0115    time: 0.1867  last_time: 0.2074  data_time: 0.0489  last_data_time: 0.0650   lr: 0.00093906  max_mem: 943M
# Logged iteration 940
# [06/08 05:14:35 d2.utils.events]:  eta: 0:00:07  iter: 959  total_loss: 0.01327  loss_rpn_cls: 0.004342  loss_rpn_loc: 0.008291    time: 0.1868  last_time: 0.1732  data_time: 0.0551  last_data_time: 0.0598   lr: 0.00095904  max_mem: 943M
# Logged iteration 960
# [06/08 05:14:39 d2.utils.events]:  eta: 0:00:03  iter: 979  total_loss: 0.01467  loss_rpn_cls: 0.003353  loss_rpn_loc: 0.01079    time: 0.1870  last_time: 0.1991  data_time: 0.0626  last_data_time: 0.0554   lr: 0.00097902  max_mem: 944M
# Logged iteration 980
# [06/08 05:14:43 d2.utils.events]:  eta: 0:00:00  iter: 999  total_loss: 0.01741  loss_rpn_cls: 0.00457  loss_rpn_loc: 0.01269    time: 0.1870  last_time: 0.1741  data_time: 0.0518  last_data_time: 0.0488   lr: 0.000999  max_mem: 944M
# [06/08 05:14:43 d2.engine.hooks]: Overall training speed: 998 iterations in 0:03:06 (0.1870 s / it)
# [06/08 05:14:43 d2.engine.hooks]: Total training time: 0:03:16 (0:00:09 on hooks)
# Starting training with learning rate: 0.001, run: 2
# [06/08 05:14:44 d2.engine.defaults]: Model:
# ProposalNetwork(
#   (backbone): ResNet(
#     (stem): BasicStem(
#       (conv1): Conv2d(
#         3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#         (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#       )
#     )
#     (res2): Sequential(
#       (0): BottleneckBlock(
#         (shortcut): Conv2d(
#           64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv1): Conv2d(
#           64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#       )
#       (1): BottleneckBlock(
#         (conv1): Conv2d(
#           256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#       )
#       (2): BottleneckBlock(
#         (conv1): Conv2d(
#           256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#       )
#     )
#     (res3): Sequential(
#       (0): BottleneckBlock(
#         (shortcut): Conv2d(
#           256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#         (conv1): Conv2d(
#           256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#       )
#       (1): BottleneckBlock(
#         (conv1): Conv2d(
#           512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#       )
#       (2): BottleneckBlock(
#         (conv1): Conv2d(
#           512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#       )
#       (3): BottleneckBlock(
#         (conv1): Conv2d(
#           512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#       )
#     )
#     (res4): Sequential(
#       (0): BottleneckBlock(
#         (shortcut): Conv2d(
#           512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#         (conv1): Conv2d(
#           512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#       )
#       (1): BottleneckBlock(
#         (conv1): Conv2d(
#           1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#       )
#       (2): BottleneckBlock(
#         (conv1): Conv2d(
#           1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#       )
#       (3): BottleneckBlock(
#         (conv1): Conv2d(
#           1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#       )
#       (4): BottleneckBlock(
#         (conv1): Conv2d(
#           1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#       )
#       (5): BottleneckBlock(
#         (conv1): Conv2d(
#           1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(
#         1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (objectness_logits): Conv2d(1024, 15, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(1024, 60, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
# )
# [06/08 05:14:44 d2.data.datasets.coco]: Loaded 222 images in COCO format from /kaggle/input/tomatod/annotations/tomatOD_train.json
# [06/08 05:14:44 d2.data.build]: Removed 0 images with no usable annotations. 222 images left.
# [06/08 05:14:44 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), RandomFlip()]
# [06/08 05:14:44 d2.data.build]: Using training sampler TrainingSampler
# [06/08 05:14:44 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [06/08 05:14:44 d2.data.common]: Serializing 222 elements to byte tensors and concatenating them all ...
# [06/08 05:14:44 d2.data.common]: Serialized dataset takes 0.10 MiB
# [06/08 05:14:44 d2.data.build]: Making batched data loader with batch_size=2
# [06/08 05:14:44 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from https://dl.fbaipublicfiles.com/detectron2/COCO-Detection/rpn_R_50_C4_1x/137258005/model_final_450694.pkl ...
# [06/08 05:14:44 d2.engine.train_loop]: Starting training from iteration 0
# Logged iteration 0
# [06/08 05:14:48 d2.utils.events]:  eta: 0:03:28  iter: 19  total_loss: 0.1397  loss_rpn_cls: 0.1276  loss_rpn_loc: 0.01371    time: 0.2119  last_time: 0.1926  data_time: 0.0947  last_data_time: 0.0565   lr: 1.9981e-05  max_mem: 944M
# Logged iteration 20
# [06/08 05:14:52 d2.utils.events]:  eta: 0:03:06  iter: 39  total_loss: 0.1271  loss_rpn_cls: 0.1124  loss_rpn_loc: 0.01701    time: 0.1961  last_time: 0.1738  data_time: 0.0600  last_data_time: 0.0569   lr: 3.9961e-05  max_mem: 944M
# Logged iteration 40
# [06/08 05:14:56 d2.utils.events]:  eta: 0:03:01  iter: 59  total_loss: 0.0904  loss_rpn_cls: 0.06825  loss_rpn_loc: 0.01642    time: 0.1910  last_time: 0.1950  data_time: 0.0554  last_data_time: 0.0708   lr: 5.9941e-05  max_mem: 945M
# Logged iteration 60
# [06/08 05:14:59 d2.utils.events]:  eta: 0:02:47  iter: 79  total_loss: 0.072  loss_rpn_cls: 0.056  loss_rpn_loc: 0.01587    time: 0.1883  last_time: 0.1773  data_time: 0.0580  last_data_time: 0.0520   lr: 7.9921e-05  max_mem: 945M
# Logged iteration 80
# [06/08 05:15:03 d2.utils.events]:  eta: 0:02:44  iter: 99  total_loss: 0.06079  loss_rpn_cls: 0.04663  loss_rpn_loc: 0.01399    time: 0.1873  last_time: 0.2040  data_time: 0.0558  last_data_time: 0.0614   lr: 9.9901e-05  max_mem: 945M
# Logged iteration 100
# [06/08 05:15:07 d2.utils.events]:  eta: 0:02:42  iter: 119  total_loss: 0.05119  loss_rpn_cls: 0.03692  loss_rpn_loc: 0.01271    time: 0.1872  last_time: 0.1812  data_time: 0.0560  last_data_time: 0.0416   lr: 0.00011988  max_mem: 945M
# Logged iteration 120
# [06/08 05:15:10 d2.utils.events]:  eta: 0:02:38  iter: 139  total_loss: 0.04319  loss_rpn_cls: 0.03032  loss_rpn_loc: 0.01278    time: 0.1869  last_time: 0.1861  data_time: 0.0582  last_data_time: 0.0617   lr: 0.00013986  max_mem: 945M
# Logged iteration 140
# [06/08 05:15:14 d2.utils.events]:  eta: 0:02:35  iter: 159  total_loss: 0.03929  loss_rpn_cls: 0.02417  loss_rpn_loc: 0.01188    time: 0.1866  last_time: 0.2354  data_time: 0.0558  last_data_time: 0.0931   lr: 0.00015984  max_mem: 945M
# Logged iteration 160
# [06/08 05:15:18 d2.utils.events]:  eta: 0:02:32  iter: 179  total_loss: 0.03411  loss_rpn_cls: 0.02293  loss_rpn_loc: 0.01413    time: 0.1869  last_time: 0.2003  data_time: 0.0606  last_data_time: 0.0737   lr: 0.00017982  max_mem: 945M
# Logged iteration 180
# [06/08 05:15:22 d2.utils.events]:  eta: 0:02:28  iter: 199  total_loss: 0.02971  loss_rpn_cls: 0.01784  loss_rpn_loc: 0.01212    time: 0.1872  last_time: 0.2047  data_time: 0.0555  last_data_time: 0.0664   lr: 0.0001998  max_mem: 945M
# Logged iteration 200
# [06/08 05:15:26 d2.utils.events]:  eta: 0:02:24  iter: 219  total_loss: 0.03106  loss_rpn_cls: 0.01827  loss_rpn_loc: 0.01351    time: 0.1867  last_time: 0.1888  data_time: 0.0526  last_data_time: 0.0607   lr: 0.00021978  max_mem: 945M
# Logged iteration 220
# [06/08 05:15:30 d2.utils.events]:  eta: 0:02:21  iter: 239  total_loss: 0.02561  loss_rpn_cls: 0.01261  loss_rpn_loc: 0.014    time: 0.1868  last_time: 0.1861  data_time: 0.0545  last_data_time: 0.0596   lr: 0.00023976  max_mem: 945M
# Logged iteration 240
# [06/08 05:15:33 d2.utils.events]:  eta: 0:02:17  iter: 259  total_loss: 0.02947  loss_rpn_cls: 0.01621  loss_rpn_loc: 0.01349    time: 0.1869  last_time: 0.1992  data_time: 0.0591  last_data_time: 0.0659   lr: 0.00025974  max_mem: 945M
# Logged iteration 260
# [06/08 05:15:37 d2.utils.events]:  eta: 0:02:14  iter: 279  total_loss: 0.0283  loss_rpn_cls: 0.0162  loss_rpn_loc: 0.01306    time: 0.1869  last_time: 0.1848  data_time: 0.0558  last_data_time: 0.0456   lr: 0.00027972  max_mem: 945M
# Logged iteration 280
# [06/08 05:15:41 d2.utils.events]:  eta: 0:02:10  iter: 299  total_loss: 0.03354  loss_rpn_cls: 0.01772  loss_rpn_loc: 0.01471    time: 0.1867  last_time: 0.1629  data_time: 0.0580  last_data_time: 0.0367   lr: 0.0002997  max_mem: 945M
# Logged iteration 300
# [06/08 05:15:45 d2.utils.events]:  eta: 0:02:06  iter: 319  total_loss: 0.0223  loss_rpn_cls: 0.01223  loss_rpn_loc: 0.009789    time: 0.1866  last_time: 0.1640  data_time: 0.0582  last_data_time: 0.0438   lr: 0.00031968  max_mem: 945M
# Logged iteration 320
# [06/08 05:15:48 d2.utils.events]:  eta: 0:02:02  iter: 339  total_loss: 0.02252  loss_rpn_cls: 0.01163  loss_rpn_loc: 0.01101    time: 0.1862  last_time: 0.1850  data_time: 0.0477  last_data_time: 0.0554   lr: 0.00033966  max_mem: 945M
# Logged iteration 340
# [06/08 05:15:52 d2.utils.events]:  eta: 0:01:58  iter: 359  total_loss: 0.02734  loss_rpn_cls: 0.01445  loss_rpn_loc: 0.01258    time: 0.1871  last_time: 0.2056  data_time: 0.0669  last_data_time: 0.0637   lr: 0.00035964  max_mem: 945M
# Logged iteration 360
# [06/08 05:15:56 d2.utils.events]:  eta: 0:01:55  iter: 379  total_loss: 0.02316  loss_rpn_cls: 0.01096  loss_rpn_loc: 0.01147    time: 0.1868  last_time: 0.1888  data_time: 0.0568  last_data_time: 0.0608   lr: 0.00037962  max_mem: 945M
# Logged iteration 380
# [06/08 05:16:00 d2.utils.events]:  eta: 0:01:51  iter: 399  total_loss: 0.02256  loss_rpn_cls: 0.009248  loss_rpn_loc: 0.01159    time: 0.1867  last_time: 0.1581  data_time: 0.0557  last_data_time: 0.0318   lr: 0.0003996  max_mem: 945M
# Logged iteration 400
# [06/08 05:16:03 d2.utils.events]:  eta: 0:01:47  iter: 419  total_loss: 0.02177  loss_rpn_cls: 0.01118  loss_rpn_loc: 0.0117    time: 0.1865  last_time: 0.2111  data_time: 0.0555  last_data_time: 0.0694   lr: 0.00041958  max_mem: 945M
# Logged iteration 420
# [06/08 05:16:07 d2.utils.events]:  eta: 0:01:43  iter: 439  total_loss: 0.02044  loss_rpn_cls: 0.01021  loss_rpn_loc: 0.01136    time: 0.1865  last_time: 0.1657  data_time: 0.0542  last_data_time: 0.0261   lr: 0.00043956  max_mem: 945M
# Logged iteration 440
# [06/08 05:16:11 d2.utils.events]:  eta: 0:01:40  iter: 459  total_loss: 0.02373  loss_rpn_cls: 0.01044  loss_rpn_loc: 0.01119    time: 0.1867  last_time: 0.1994  data_time: 0.0644  last_data_time: 0.0601   lr: 0.00045954  max_mem: 945M
# Logged iteration 460
# [06/08 05:16:14 d2.utils.events]:  eta: 0:01:36  iter: 479  total_loss: 0.0247  loss_rpn_cls: 0.01018  loss_rpn_loc: 0.01238    time: 0.1866  last_time: 0.2180  data_time: 0.0578  last_data_time: 0.0950   lr: 0.00047952  max_mem: 945M
# Logged iteration 480
# [06/08 05:16:18 d2.utils.events]:  eta: 0:01:33  iter: 499  total_loss: 0.02698  loss_rpn_cls: 0.01237  loss_rpn_loc: 0.014    time: 0.1864  last_time: 0.1369  data_time: 0.0559  last_data_time: 0.0242   lr: 0.0004995  max_mem: 945M
# Logged iteration 500
# [06/08 05:16:22 d2.utils.events]:  eta: 0:01:29  iter: 519  total_loss: 0.023  loss_rpn_cls: 0.009962  loss_rpn_loc: 0.01089    time: 0.1865  last_time: 0.2254  data_time: 0.0572  last_data_time: 0.0909   lr: 0.00051948  max_mem: 945M
# Logged iteration 520
# [06/08 05:16:26 d2.utils.events]:  eta: 0:01:25  iter: 539  total_loss: 0.02004  loss_rpn_cls: 0.007235  loss_rpn_loc: 0.01109    time: 0.1867  last_time: 0.1995  data_time: 0.0557  last_data_time: 0.0562   lr: 0.00053946  max_mem: 945M
# Logged iteration 540
# [06/08 05:16:29 d2.utils.events]:  eta: 0:01:21  iter: 559  total_loss: 0.01986  loss_rpn_cls: 0.009291  loss_rpn_loc: 0.01223    time: 0.1866  last_time: 0.1632  data_time: 0.0522  last_data_time: 0.0405   lr: 0.00055944  max_mem: 945M
# Logged iteration 560
# [06/08 05:16:33 d2.utils.events]:  eta: 0:01:17  iter: 579  total_loss: 0.01853  loss_rpn_cls: 0.00787  loss_rpn_loc: 0.01018    time: 0.1862  last_time: 0.1904  data_time: 0.0466  last_data_time: 0.0616   lr: 0.00057942  max_mem: 945M
# Logged iteration 580
# [06/08 05:16:37 d2.utils.events]:  eta: 0:01:14  iter: 599  total_loss: 0.02556  loss_rpn_cls: 0.01156  loss_rpn_loc: 0.01238    time: 0.1863  last_time: 0.1881  data_time: 0.0596  last_data_time: 0.0590   lr: 0.0005994  max_mem: 945M
# Logged iteration 600
# [06/08 05:16:41 d2.utils.events]:  eta: 0:01:10  iter: 619  total_loss: 0.01646  loss_rpn_cls: 0.00607  loss_rpn_loc: 0.011    time: 0.1863  last_time: 0.1976  data_time: 0.0581  last_data_time: 0.0679   lr: 0.00061938  max_mem: 945M
# Logged iteration 620
# [06/08 05:16:44 d2.utils.events]:  eta: 0:01:06  iter: 639  total_loss: 0.01589  loss_rpn_cls: 0.005913  loss_rpn_loc: 0.01024    time: 0.1864  last_time: 0.2047  data_time: 0.0617  last_data_time: 0.0740   lr: 0.00063936  max_mem: 945M
# Logged iteration 640
# [06/08 05:16:48 d2.utils.events]:  eta: 0:01:03  iter: 659  total_loss: 0.02132  loss_rpn_cls: 0.008063  loss_rpn_loc: 0.01221    time: 0.1865  last_time: 0.1842  data_time: 0.0600  last_data_time: 0.0584   lr: 0.00065934  max_mem: 945M
# Logged iteration 660
# [06/08 05:16:52 d2.utils.events]:  eta: 0:00:59  iter: 679  total_loss: 0.01846  loss_rpn_cls: 0.006381  loss_rpn_loc: 0.01192    time: 0.1868  last_time: 0.1790  data_time: 0.0655  last_data_time: 0.0500   lr: 0.00067932  max_mem: 945M
# Logged iteration 680
# [06/08 05:16:56 d2.utils.events]:  eta: 0:00:55  iter: 699  total_loss: 0.01829  loss_rpn_cls: 0.006236  loss_rpn_loc: 0.012    time: 0.1873  last_time: 0.2158  data_time: 0.0706  last_data_time: 0.0713   lr: 0.0006993  max_mem: 945M
# Logged iteration 700
# [06/08 05:17:00 d2.utils.events]:  eta: 0:00:52  iter: 719  total_loss: 0.01442  loss_rpn_cls: 0.005127  loss_rpn_loc: 0.009331    time: 0.1872  last_time: 0.2035  data_time: 0.0546  last_data_time: 0.0690   lr: 0.00071928  max_mem: 945M
# Logged iteration 720
# [06/08 05:17:03 d2.utils.events]:  eta: 0:00:48  iter: 739  total_loss: 0.01665  loss_rpn_cls: 0.005685  loss_rpn_loc: 0.009677    time: 0.1870  last_time: 0.1579  data_time: 0.0525  last_data_time: 0.0314   lr: 0.00073926  max_mem: 945M
# Logged iteration 740
# [06/08 05:17:07 d2.utils.events]:  eta: 0:00:44  iter: 759  total_loss: 0.02008  loss_rpn_cls: 0.007402  loss_rpn_loc: 0.01369    time: 0.1869  last_time: 0.1453  data_time: 0.0524  last_data_time: 0.0190   lr: 0.00075924  max_mem: 945M
# Logged iteration 760
# [06/08 05:17:11 d2.utils.events]:  eta: 0:00:40  iter: 779  total_loss: 0.01585  loss_rpn_cls: 0.005304  loss_rpn_loc: 0.009753    time: 0.1870  last_time: 0.1945  data_time: 0.0574  last_data_time: 0.0505   lr: 0.00077922  max_mem: 945M
# Logged iteration 780
# [06/08 05:17:15 d2.utils.events]:  eta: 0:00:37  iter: 799  total_loss: 0.01595  loss_rpn_cls: 0.005717  loss_rpn_loc: 0.01025    time: 0.1871  last_time: 0.1938  data_time: 0.0609  last_data_time: 0.0625   lr: 0.0007992  max_mem: 945M
# Logged iteration 800
# [06/08 05:17:19 d2.utils.events]:  eta: 0:00:33  iter: 819  total_loss: 0.01724  loss_rpn_cls: 0.007032  loss_rpn_loc: 0.0112    time: 0.1871  last_time: 0.1546  data_time: 0.0573  last_data_time: 0.0372   lr: 0.00081918  max_mem: 945M
# Logged iteration 820
# [06/08 05:17:22 d2.utils.events]:  eta: 0:00:29  iter: 839  total_loss: 0.0208  loss_rpn_cls: 0.006758  loss_rpn_loc: 0.01263    time: 0.1872  last_time: 0.2125  data_time: 0.0601  last_data_time: 0.0733   lr: 0.00083916  max_mem: 945M
# Logged iteration 840
# [06/08 05:17:26 d2.utils.events]:  eta: 0:00:26  iter: 859  total_loss: 0.01884  loss_rpn_cls: 0.005624  loss_rpn_loc: 0.01284    time: 0.1875  last_time: 0.2650  data_time: 0.0658  last_data_time: 0.1132   lr: 0.00085914  max_mem: 945M
# Logged iteration 860
# [06/08 05:17:30 d2.utils.events]:  eta: 0:00:22  iter: 879  total_loss: 0.01396  loss_rpn_cls: 0.003824  loss_rpn_loc: 0.01025    time: 0.1874  last_time: 0.2038  data_time: 0.0480  last_data_time: 0.0608   lr: 0.00087912  max_mem: 945M
# Logged iteration 880
# [06/08 05:17:34 d2.utils.events]:  eta: 0:00:18  iter: 899  total_loss: 0.02191  loss_rpn_cls: 0.008738  loss_rpn_loc: 0.01262    time: 0.1874  last_time: 0.2134  data_time: 0.0560  last_data_time: 0.0720   lr: 0.0008991  max_mem: 945M
# Logged iteration 900
# [06/08 05:17:38 d2.utils.events]:  eta: 0:00:14  iter: 919  total_loss: 0.02095  loss_rpn_cls: 0.007859  loss_rpn_loc: 0.01339    time: 0.1873  last_time: 0.2024  data_time: 0.0557  last_data_time: 0.0758   lr: 0.00091908  max_mem: 945M
# Logged iteration 920
# [06/08 05:17:41 d2.utils.events]:  eta: 0:00:11  iter: 939  total_loss: 0.01521  loss_rpn_cls: 0.005277  loss_rpn_loc: 0.01006    time: 0.1872  last_time: 0.1777  data_time: 0.0528  last_data_time: 0.0622   lr: 0.00093906  max_mem: 945M
# Logged iteration 940
# [06/08 05:17:45 d2.utils.events]:  eta: 0:00:07  iter: 959  total_loss: 0.01609  loss_rpn_cls: 0.005705  loss_rpn_loc: 0.008778    time: 0.1871  last_time: 0.1150  data_time: 0.0532  last_data_time: 0.0060   lr: 0.00095904  max_mem: 945M
# Logged iteration 960
# [06/08 05:17:49 d2.utils.events]:  eta: 0:00:03  iter: 979  total_loss: 0.01631  loss_rpn_cls: 0.005296  loss_rpn_loc: 0.01015    time: 0.1871  last_time: 0.2066  data_time: 0.0566  last_data_time: 0.0763   lr: 0.00097902  max_mem: 945M
# Logged iteration 980
# [06/08 05:17:53 d2.utils.events]:  eta: 0:00:00  iter: 999  total_loss: 0.01587  loss_rpn_cls: 0.005096  loss_rpn_loc: 0.009411    time: 0.1870  last_time: 0.2131  data_time: 0.0563  last_data_time: 0.0846   lr: 0.000999  max_mem: 945M
# [06/08 05:17:53 d2.engine.hooks]: Overall training speed: 998 iterations in 0:03:06 (0.1870 s / it)
# [06/08 05:17:53 d2.engine.hooks]: Total training time: 0:03:08 (0:00:01 on hooks)
# Starting training with learning rate: 0.001, run: 3
# [06/08 05:17:54 d2.engine.defaults]: Model:
# ProposalNetwork(
#   (backbone): ResNet(
#     (stem): BasicStem(
#       (conv1): Conv2d(
#         3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#         (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#       )
#     )
#     (res2): Sequential(
#       (0): BottleneckBlock(
#         (shortcut): Conv2d(
#           64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv1): Conv2d(
#           64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#       )
#       (1): BottleneckBlock(
#         (conv1): Conv2d(
#           256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
# ...
# Logged iteration 180
# [06/08 06:45:33 d2.utils.events]:  eta: 0:02:27  iter: 199  total_loss: 0.0192  loss_rpn_cls: 0.006913  loss_rpn_loc: 0.01207    time: 0.1860  last_time: 0.1989  data_time: 0.0531  last_data_time: 0.0571   lr: 0.001998  max_mem: 947M
# Logged iteration 200
# [06/08 06:45:37 d2.utils.events]:  eta: 0:02:24  iter: 219  total_loss: 0.01722  loss_rpn_cls: 0.005986  loss_rpn_loc: 0.01017    time: 0.1864  last_time: 0.1992  data_time: 0.0598  last_data_time: 0.0707   lr: 0.0021978  max_mem: 947M
# Logged iteration 220
# [06/08 06:45:41 d2.utils.events]:  eta: 0:02:20  iter: 239  total_loss: 0.01822  loss_rpn_cls: 0.005801  loss_rpn_loc: 0.01173    time: 0.1874  last_time: 0.2646  data_time: 0.0677  last_data_time: 0.1215   lr: 0.0023976  max_mem: 947M
# Logged iteration 240
# [06/08 06:45:45 d2.utils.events]:  eta: 0:02:18  iter: 259  total_loss: 0.0209  loss_rpn_cls: 0.008209  loss_rpn_loc: 0.01214    time: 0.1881  last_time: 0.1840  data_time: 0.0640  last_data_time: 0.0621   lr: 0.0025974  max_mem: 947M
# Logged iteration 260
# [06/08 06:45:49 d2.utils.events]:  eta: 0:02:14  iter: 279  total_loss: 0.0187  loss_rpn_cls: 0.005894  loss_rpn_loc: 0.01185    time: 0.1881  last_time: 0.1804  data_time: 0.0614  last_data_time: 0.0587   lr: 0.0027972  max_mem: 947M
# Logged iteration 280
# [06/08 06:45:52 d2.utils.events]:  eta: 0:02:11  iter: 299  total_loss: 0.01374  loss_rpn_cls: 0.004415  loss_rpn_loc: 0.008872    time: 0.1885  last_time: 0.2108  data_time: 0.0627  last_data_time: 0.0695   lr: 0.002997  max_mem: 947M
# Logged iteration 300
# [06/08 06:45:56 d2.utils.events]:  eta: 0:02:07  iter: 319  total_loss: 0.01882  loss_rpn_cls: 0.005705  loss_rpn_loc: 0.01346    time: 0.1884  last_time: 0.1869  data_time: 0.0601  last_data_time: 0.0599   lr: 0.0031968  max_mem: 947M
# Logged iteration 320
# [06/08 06:46:00 d2.utils.events]:  eta: 0:02:03  iter: 339  total_loss: 0.01663  loss_rpn_cls: 0.005896  loss_rpn_loc: 0.01091    time: 0.1883  last_time: 0.2076  data_time: 0.0581  last_data_time: 0.0705   lr: 0.0033966  max_mem: 947M
# Logged iteration 340
# [06/08 06:46:04 d2.utils.events]:  eta: 0:01:59  iter: 359  total_loss: 0.01571  loss_rpn_cls: 0.002949  loss_rpn_loc: 0.01066    time: 0.1877  last_time: 0.1722  data_time: 0.0506  last_data_time: 0.0599   lr: 0.0035964  max_mem: 947M
# Logged iteration 360
# [06/08 06:46:07 d2.utils.events]:  eta: 0:01:55  iter: 379  total_loss: 0.0171  loss_rpn_cls: 0.005507  loss_rpn_loc: 0.009556    time: 0.1876  last_time: 0.1890  data_time: 0.0542  last_data_time: 0.0607   lr: 0.0037962  max_mem: 947M
# Logged iteration 380
# [06/08 06:46:11 d2.utils.events]:  eta: 0:01:52  iter: 399  total_loss: 0.01766  loss_rpn_cls: 0.004997  loss_rpn_loc: 0.01379    time: 0.1874  last_time: 0.2029  data_time: 0.0582  last_data_time: 0.0654   lr: 0.003996  max_mem: 947M
# Logged iteration 400
# [06/08 06:46:15 d2.utils.events]:  eta: 0:01:48  iter: 419  total_loss: 0.01802  loss_rpn_cls: 0.00603  loss_rpn_loc: 0.0117    time: 0.1881  last_time: 0.2107  data_time: 0.0666  last_data_time: 0.0716   lr: 0.0041958  max_mem: 947M
# Logged iteration 420
# [06/08 06:46:19 d2.utils.events]:  eta: 0:01:44  iter: 439  total_loss: 0.01904  loss_rpn_cls: 0.006112  loss_rpn_loc: 0.01246    time: 0.1880  last_time: 0.2067  data_time: 0.0544  last_data_time: 0.0751   lr: 0.0043956  max_mem: 947M
# Logged iteration 440
# [06/08 06:46:22 d2.utils.events]:  eta: 0:01:41  iter: 459  total_loss: 0.01732  loss_rpn_cls: 0.005016  loss_rpn_loc: 0.01228    time: 0.1881  last_time: 0.1839  data_time: 0.0610  last_data_time: 0.0558   lr: 0.0045954  max_mem: 947M
# Logged iteration 460
# [06/08 06:46:26 d2.utils.events]:  eta: 0:01:37  iter: 479  total_loss: 0.01555  loss_rpn_cls: 0.003403  loss_rpn_loc: 0.01258    time: 0.1883  last_time: 0.1739  data_time: 0.0643  last_data_time: 0.0669   lr: 0.0047952  max_mem: 947M
# Logged iteration 480
# [06/08 06:46:30 d2.utils.events]:  eta: 0:01:33  iter: 499  total_loss: 0.01668  loss_rpn_cls: 0.004108  loss_rpn_loc: 0.01261    time: 0.1880  last_time: 0.2140  data_time: 0.0549  last_data_time: 0.0718   lr: 0.004995  max_mem: 947M
# Logged iteration 500
# [06/08 06:46:34 d2.utils.events]:  eta: 0:01:30  iter: 519  total_loss: 0.01887  loss_rpn_cls: 0.005602  loss_rpn_loc: 0.01202    time: 0.1878  last_time: 0.1954  data_time: 0.0558  last_data_time: 0.0651   lr: 0.0051948  max_mem: 947M
# Logged iteration 520
# [06/08 06:46:37 d2.utils.events]:  eta: 0:01:26  iter: 539  total_loss: 0.01321  loss_rpn_cls: 0.003424  loss_rpn_loc: 0.01012    time: 0.1876  last_time: 0.1842  data_time: 0.0518  last_data_time: 0.0572   lr: 0.0053946  max_mem: 947M
# Logged iteration 540
# [06/08 06:46:41 d2.utils.events]:  eta: 0:01:22  iter: 559  total_loss: 0.01531  loss_rpn_cls: 0.003329  loss_rpn_loc: 0.01193    time: 0.1875  last_time: 0.2026  data_time: 0.0596  last_data_time: 0.0639   lr: 0.0055944  max_mem: 947M
# Logged iteration 560
# [06/08 06:46:45 d2.utils.events]:  eta: 0:01:18  iter: 579  total_loss: 0.01421  loss_rpn_cls: 0.004133  loss_rpn_loc: 0.008784    time: 0.1876  last_time: 0.2348  data_time: 0.0575  last_data_time: 0.0832   lr: 0.0057942  max_mem: 947M
# Logged iteration 580
# [06/08 06:46:49 d2.utils.events]:  eta: 0:01:15  iter: 599  total_loss: 0.01511  loss_rpn_cls: 0.005497  loss_rpn_loc: 0.009363    time: 0.1878  last_time: 0.1609  data_time: 0.0601  last_data_time: 0.0295   lr: 0.005994  max_mem: 947M
# Logged iteration 600
# [06/08 06:46:52 d2.utils.events]:  eta: 0:01:11  iter: 619  total_loss: 0.01543  loss_rpn_cls: 0.003601  loss_rpn_loc: 0.01161    time: 0.1878  last_time: 0.1999  data_time: 0.0547  last_data_time: 0.0538   lr: 0.0061938  max_mem: 947M
# Logged iteration 620
# [06/08 06:46:56 d2.utils.events]:  eta: 0:01:07  iter: 639  total_loss: 0.01728  loss_rpn_cls: 0.004468  loss_rpn_loc: 0.01141    time: 0.1879  last_time: 0.1884  data_time: 0.0620  last_data_time: 0.0486   lr: 0.0063936  max_mem: 947M
# Logged iteration 640
# [06/08 06:47:00 d2.utils.events]:  eta: 0:01:03  iter: 659  total_loss: 0.01372  loss_rpn_cls: 0.00362  loss_rpn_loc: 0.01032    time: 0.1877  last_time: 0.2041  data_time: 0.0523  last_data_time: 0.0639   lr: 0.0065934  max_mem: 947M
# Logged iteration 660
# [06/08 06:47:04 d2.utils.events]:  eta: 0:01:00  iter: 679  total_loss: 0.0155  loss_rpn_cls: 0.003842  loss_rpn_loc: 0.01171    time: 0.1877  last_time: 0.1672  data_time: 0.0576  last_data_time: 0.0280   lr: 0.0067932  max_mem: 947M
# Logged iteration 680
# [06/08 06:47:07 d2.utils.events]:  eta: 0:00:56  iter: 699  total_loss: 0.01644  loss_rpn_cls: 0.002928  loss_rpn_loc: 0.01244    time: 0.1875  last_time: 0.1653  data_time: 0.0566  last_data_time: 0.0321   lr: 0.006993  max_mem: 947M
# Logged iteration 700
# [06/08 06:47:11 d2.utils.events]:  eta: 0:00:52  iter: 719  total_loss: 0.01233  loss_rpn_cls: 0.002833  loss_rpn_loc: 0.01028    time: 0.1875  last_time: 0.2103  data_time: 0.0616  last_data_time: 0.0868   lr: 0.0071928  max_mem: 947M
# Logged iteration 720
# [06/08 06:47:15 d2.utils.events]:  eta: 0:00:48  iter: 739  total_loss: 0.01707  loss_rpn_cls: 0.004893  loss_rpn_loc: 0.01089    time: 0.1875  last_time: 0.1524  data_time: 0.0591  last_data_time: 0.0176   lr: 0.0073926  max_mem: 947M
# Logged iteration 740
# [06/08 06:47:19 d2.utils.events]:  eta: 0:00:45  iter: 759  total_loss: 0.01156  loss_rpn_cls: 0.003182  loss_rpn_loc: 0.008389    time: 0.1880  last_time: 0.2242  data_time: 0.0738  last_data_time: 0.0993   lr: 0.0075924  max_mem: 947M
# Logged iteration 760
# [06/08 06:47:23 d2.utils.events]:  eta: 0:00:41  iter: 779  total_loss: 0.0133  loss_rpn_cls: 0.003471  loss_rpn_loc: 0.01014    time: 0.1880  last_time: 0.1947  data_time: 0.0590  last_data_time: 0.0561   lr: 0.0077922  max_mem: 947M
# Logged iteration 780
# [06/08 06:47:27 d2.utils.events]:  eta: 0:00:37  iter: 799  total_loss: 0.01536  loss_rpn_cls: 0.003682  loss_rpn_loc: 0.01101    time: 0.1881  last_time: 0.1852  data_time: 0.0656  last_data_time: 0.0615   lr: 0.007992  max_mem: 947M
# Logged iteration 800
# [06/08 06:47:30 d2.utils.events]:  eta: 0:00:33  iter: 819  total_loss: 0.0127  loss_rpn_cls: 0.002098  loss_rpn_loc: 0.01088    time: 0.1880  last_time: 0.1609  data_time: 0.0559  last_data_time: 0.0388   lr: 0.0081918  max_mem: 947M
# Logged iteration 820
# [06/08 06:47:34 d2.utils.events]:  eta: 0:00:30  iter: 839  total_loss: 0.01498  loss_rpn_cls: 0.001581  loss_rpn_loc: 0.01188    time: 0.1881  last_time: 0.1683  data_time: 0.0664  last_data_time: 0.0304   lr: 0.0083916  max_mem: 947M
# Logged iteration 840
# [06/08 06:47:38 d2.utils.events]:  eta: 0:00:26  iter: 859  total_loss: 0.01386  loss_rpn_cls: 0.002234  loss_rpn_loc: 0.01026    time: 0.1879  last_time: 0.1903  data_time: 0.0547  last_data_time: 0.0599   lr: 0.0085914  max_mem: 947M
# Logged iteration 860
# [06/08 06:47:41 d2.utils.events]:  eta: 0:00:22  iter: 879  total_loss: 0.01254  loss_rpn_cls: 0.002417  loss_rpn_loc: 0.009757    time: 0.1877  last_time: 0.1982  data_time: 0.0494  last_data_time: 0.0594   lr: 0.0087912  max_mem: 947M
# Logged iteration 880
# [06/08 06:47:45 d2.utils.events]:  eta: 0:00:18  iter: 899  total_loss: 0.01341  loss_rpn_cls: 0.002279  loss_rpn_loc: 0.009692    time: 0.1876  last_time: 0.1730  data_time: 0.0570  last_data_time: 0.0586   lr: 0.008991  max_mem: 947M
# Logged iteration 900
# [06/08 06:47:49 d2.utils.events]:  eta: 0:00:15  iter: 919  total_loss: 0.01321  loss_rpn_cls: 0.002332  loss_rpn_loc: 0.01155    time: 0.1877  last_time: 0.2159  data_time: 0.0623  last_data_time: 0.0850   lr: 0.0091908  max_mem: 947M
# Logged iteration 920
# [06/08 06:47:53 d2.utils.events]:  eta: 0:00:11  iter: 939  total_loss: 0.01909  loss_rpn_cls: 0.003843  loss_rpn_loc: 0.01341    time: 0.1880  last_time: 0.1633  data_time: 0.0705  last_data_time: 0.0558   lr: 0.0093906  max_mem: 947M
# Logged iteration 940
# [06/08 06:47:57 d2.utils.events]:  eta: 0:00:07  iter: 959  total_loss: 0.01444  loss_rpn_cls: 0.00292  loss_rpn_loc: 0.01126    time: 0.1879  last_time: 0.1851  data_time: 0.0571  last_data_time: 0.0442   lr: 0.0095904  max_mem: 947M
# Logged iteration 960
# [06/08 06:48:01 d2.utils.events]:  eta: 0:00:03  iter: 979  total_loss: 0.01537  loss_rpn_cls: 0.002456  loss_rpn_loc: 0.01159    time: 0.1880  last_time: 0.1977  data_time: 0.0632  last_data_time: 0.0610   lr: 0.0097902  max_mem: 947M
# Logged iteration 980
# [06/08 06:48:05 d2.utils.events]:  eta: 0:00:00  iter: 999  total_loss: 0.0164  loss_rpn_cls: 0.00381  loss_rpn_loc: 0.01221    time: 0.1879  last_time: 0.2203  data_time: 0.0651  last_data_time: 0.0816   lr: 0.00999  max_mem: 947M
# [06/08 06:48:05 d2.engine.hooks]: Overall training speed: 998 iterations in 0:03:07 (0.1880 s / it)
# [06/08 06:48:05 d2.engine.hooks]: Total training time: 0:03:09 (0:00:01 on hooks)
#   Learning Rate    Run  Minimum Loss                    Duration (s)
# ---------------  -----  ----------------------------  --------------
#        0.001000      1  (0.003600790980271995, 979)       200.371612
#        0.001000      2  (0.003635437518823892, 737)       189.291428
#        0.001000      3  (0.002888588060159236, 898)       188.876959
#        0.001000      4  (0.003956912085413933, 781)       190.028882
#        0.001000      5  (0.004321263113524765, 911)       188.626289
#        0.001000      6  (0.0053513189777731895, 901)      187.910514
#        0.001000      7  (0.004259648383595049, 743)       189.011165
#        0.001000      8  (0.0028542979853227735, 837)      190.722731
#        0.001000      9  (0.0046212144661694765, 624)      189.365009
#        0.001000     10  (0.0037413759855553508, 976)      211.011207
#        0.005000      1  (0.002837381325662136, 740)       187.085047
#        0.005000      2  (0.0036699767515528947, 524)      189.564725
#        0.005000      3  (0.004106750435312279, 965)       213.107153
#        0.005000      4  (0.0043109449907206, 916)         186.682295
#        0.005000      5  (0.001756351557560265, 902)       187.513556
#        0.005000      6  (0.0033802323741838336, 541)      189.607267
#        0.005000      7  (0.0031556931789964437, 510)      191.711527
#        0.005000      8  (0.002831352991051972, 903)       190.239349
#        0.005000      9  (0.0028754608356393874, 776)      186.131109
#        0.005000     10  (0.002595470054075122, 567)       189.430414
#        0.010000      1  (0.0023328348179347813, 982)      211.358246
#        0.010000      2  (0.004171430628048256, 500)       209.112497
#        0.010000      3  (0.002650081441970542, 908)       186.739300
#        0.010000      4  (0.0021779618691653013, 294)      187.098994
#        0.010000      5  (0.003417325555346906, 579)       187.548415
#        0.010000      6  (0.002939727986813523, 675)       189.160237
#        0.010000      7  (0.00187427326454781, 667)        191.076363
#        0.010000      8  (0.002164952995372005, 987)       186.420137
#        0.010000      9  (0.0023966766602825373, 804)      209.290647
#        0.010000     10  (0.004186268779449165, 997)       189.698755
#   Learning Rate  Minimum Loss                    Total Time (s)
# ---------------  ----------------------------  ----------------
#        0.001000  (0.0028542979853227735, 837)       1925.215796
#        0.005000  (0.001756351557560265, 902)        1911.072441
#        0.010000  (0.00187427326454781, 667)         1947.503591
#
# Detailed results for learning rate: 0.001
#   Learning Rate    Run  Minimum Loss                    Duration (s)
# ---------------  -----  ----------------------------  --------------
#        0.001000      1  (0.003600790980271995, 979)       200.371612
#        0.001000      2  (0.003635437518823892, 737)       189.291428
#        0.001000      3  (0.002888588060159236, 898)       188.876959
#        0.001000      4  (0.003956912085413933, 781)       190.028882
#        0.001000      5  (0.004321263113524765, 911)       188.626289
#        0.001000      6  (0.0053513189777731895, 901)      187.910514
#        0.001000      7  (0.004259648383595049, 743)       189.011165
#        0.001000      8  (0.0028542979853227735, 837)      190.722731
#        0.001000      9  (0.0046212144661694765, 624)      189.365009
#        0.001000     10  (0.0037413759855553508, 976)      211.011207
#
# Detailed results for learning rate: 0.005
#   Learning Rate    Run  Minimum Loss                    Duration (s)
# ---------------  -----  ----------------------------  --------------
#        0.005000      1  (0.002837381325662136, 740)       187.085047
#        0.005000      2  (0.0036699767515528947, 524)      189.564725
#        0.005000      3  (0.004106750435312279, 965)       213.107153
#        0.005000      4  (0.0043109449907206, 916)         186.682295
#        0.005000      5  (0.001756351557560265, 902)       187.513556
#        0.005000      6  (0.0033802323741838336, 541)      189.607267
#        0.005000      7  (0.0031556931789964437, 510)      191.711527
#        0.005000      8  (0.002831352991051972, 903)       190.239349
#        0.005000      9  (0.0028754608356393874, 776)      186.131109
#        0.005000     10  (0.002595470054075122, 567)       189.430414
#
# Detailed results for learning rate: 0.01
#   Learning Rate    Run  Minimum Loss                    Duration (s)
# ---------------  -----  ----------------------------  --------------
#        0.010000      1  (0.0023328348179347813, 982)      211.358246
#        0.010000      2  (0.004171430628048256, 500)       209.112497
#        0.010000      3  (0.002650081441970542, 908)       186.739300
#        0.010000      4  (0.0021779618691653013, 294)      187.098994
#        0.010000      5  (0.003417325555346906, 579)       187.548415
#        0.010000      6  (0.002939727986813523, 675)       189.160237
#        0.010000      7  (0.00187427326454781, 667)        191.076363
#        0.010000      8  (0.002164952995372005, 987)       186.420137
#        0.010000      9  (0.0023966766602825373, 804)      209.290647
#        0.010000     10  (0.004186268779449165, 997)       189.698755

# %%
import matplotlib.pyplot as plt

# Assuming `results` is a list of lists with the structure [learning_rate, run, (min_loss, iteration), duration]

# Extract data for plotting
learning_rates = sorted(set(result[0] for result in results))
num_runs = len([result for result in results if result[0] == learning_rates[0]])

# Prepare data for plotting
loss_data = {lr: [] for lr in learning_rates}
time_data = {lr: [] for lr in learning_rates}

for result in results:
    lr, run, (min_loss, _), duration = result
    loss_data[lr].append(min_loss)
    time_data[lr].append(duration)

# Plot minimum loss for each run
plt.figure(figsize=(10, 6))
for lr in learning_rates:
    plt.plot(range(1, num_runs + 1), loss_data[lr], marker='o', label=f'LR={lr}')
plt.xlabel('Run')
plt.ylabel('Minimum Loss')
plt.title('Minimum Loss for Each Run Across Different Learning Rates')
plt.legend()
plt.grid(True)
plt.show()

# Plot total time for each run
plt.figure(figsize=(10, 6))
for lr in learning_rates:
    plt.plot(range(1, num_runs + 1), time_data[lr], marker='o', label=f'LR={lr}')
plt.xlabel('Run')
plt.ylabel('Duration (s)')
plt.title('Total Time for Each Run Across Different Learning Rates')
plt.legend()
plt.grid(True)
plt.show()

# Box plot of minimum losses
plt.figure(figsize=(10, 6))
plt.boxplot([loss_data[lr] for lr in learning_rates], labels=[f'LR={lr}' for lr in learning_rates])
plt.xlabel('Learning Rate')
plt.ylabel('Minimum Loss')
plt.title('Box Plot of Minimum Losses for Each Learning Rate')
plt.grid(True)
plt.show()

# Box plot of total durations
plt.figure(figsize=(10, 6))
plt.boxplot([time_data[lr] for lr in learning_rates], labels=[f'LR={lr}' for lr in learning_rates])
plt.xlabel('Learning Rate')
plt.ylabel('Duration (s)')
plt.title('Box Plot of Total Durations for Each Learning Rate')
plt.grid(True)
plt.show()

# Scatter plot of minimum loss vs. duration
plt.figure(figsize=(10, 6))
for lr in learning_rates:
    plt.scatter(time_data[lr], loss_data[lr], label=f'LR={lr}')
plt.xlabel('Duration (s)')
plt.ylabel('Minimum Loss')
plt.title('Scatter Plot of Minimum Loss vs. Duration')
plt.legend()
plt.grid(True)
plt.show()
